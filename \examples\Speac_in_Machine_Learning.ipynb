# %% [markdown]
# <a href="https://colab.research.google.com/github/GolzitskyNikolay/SPEAC-analysis/blob/master/%5Cexamples%5CSpeac_in_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall speac
# Out:
# WARNING: Skipping speac as it is not installed.

# %%
# !pip install speac
# Out:
# Collecting speac
#   Downloading https://files.pythonhosted.org/packages/2c/04/36a05bf531078bc450b51007857b670907625775fd8088dcdc0325759cf9/speac-1.0.10-py3-none-any.whl
# Installing collected packages: speac
# Successfully installed speac-1.0.10

# %%
import speac
import music21

from speac.chopin_33_3 import CHOPIN_33_3
from speac.chopin_63_2 import CHOPIN_63_2
from speac.chopin_67_4 import CHOPIN_67_4

from speac.top_level import *
from music21 import *

# %%
import os
import pprint
import glob
import numpy
from tensorflow import keras
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import BatchNormalization as BatchNorm
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.utils import np_utils
import timeit

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Чтение хоралов Баха и их запись в форму, удобную для работы со SPEAC-анализом

# %%
  chorales = []
  signatures = []
  k = 1

  majors = dict([("A-", 4),("G#", 4),("A", 3),("A#", 2),("B-", 2),("B", 1),
                 ("C", 0),("C#", -1),("D-", -1),("D", -2),("D#", -3),("E-", -3),
                 ("E", -4),("F", -5),("F#", 6),("G-", 6),("G", 5)])   

  minors = dict([("G#", 1), ("A-", 1),("A", 0),("A#", -1),("B-", -1),("B", -2),
                 ("C", -3),("C#", -4),("D-", -4),("D", -5),("D#", 6),("E-", 6),
                 ("E", 5),("F", 4),("F#", 3),("G-", 3),("G", 2)])

  for file in glob.glob("/content/drive/My Drive/Examination/MIDI/chorales/*.mid*"):
    print("Reading file №" + str(k) + "; " + file)
    
    events = []

    k= k + 1
    main_offset = None

    midi = converter.parse(file)
    notes_to_parse = None
    parts = instrument.partitionByInstrument(midi)

    key = midi.analyze('key')
    print("key before = " + key.tonic.name, key.mode)

    if key.mode == "major":
        halfSteps = majors[key.tonic.name]

    elif key.mode == "minor":
        halfSteps = minors[key.tonic.name]

    midi = midi.transpose(halfSteps)
    key = midi.analyze('key')
    print("key after  =  " + key.tonic.name, key.mode)  

    if parts: # Если есть хотя бы 1 партия
        notes_to_parse = parts.parts[0].recurse()

    else: # file has notes in a flat structure  (не понял для чего эта ветка)
        notes_to_parse = midi.flat.notes

    #<music21.meter.TimeSignature 4/4> -> 4/4
    if midi.flat.timeSignature is not None :
      signature = str(midi.flat.timeSignature).split(" ")[1].split(">")[0].split("/")[0]
      signatures.append(signature)
    else:
      signatures.append(None)
    
    i = 1
    for element in notes_to_parse:
        if main_offset is None and (isinstance(element, note.Note) or isinstance(element, chord.Chord)):
            if element.offset == 0:
                main_offset = 0
            else:
                main_offset = element.offset

        if isinstance(element, note.Note): #Записываем ноту
            event = []
            event.append(int((element.offset - main_offset) * 1000))
            event.append(element.pitch.midi)
            event.append(int(element.duration.quarterLength * 1000))
            event.append(1)
            event.append(element.volume.velocity)
            events.append(event)

        elif isinstance(element, chord.Chord):#Записываем аккорд
            for e in element:
                if isinstance(e, note.Note):
                    event = []
                    event.append(int((element.offset - main_offset) * 1000))
                    event.append(e.pitch.midi)
                    event.append(int(e.duration.quarterLength * 1000))
                    event.append(1)
                    event.append(e.volume.velocity)
                    events.append(event)
    
    chorales.append(events)
# Out:
# Reading file №1; /content/drive/My Drive/Examination/MIDI/chorales/04esistd.mid
# key before = E major
# key after  =  C major
# Reading file №2; /content/drive/My Drive/Examination/MIDI/chorales/10austie.mid
# key before = A minor
# key after  =  A minor
# Reading file №3; /content/drive/My Drive/Examination/MIDI/chorales/01ausmei.mid
# key before = G major
# key after  =  C major
# Reading file №4; /content/drive/My Drive/Examination/MIDI/chorales/03achgot.mid
# key before = A minor
# key after  =  A minor
# Reading file №5; /content/drive/My Drive/Examination/MIDI/chorales/02ichdan.mid
# key before = A major
# key after  =  C major
# Reading file №6; /content/drive/My Drive/Examination/MIDI/chorales/09ermunt.mid
# key before = G major
# key after  =  C major
# Reading file №7; /content/drive/My Drive/Examination/MIDI/chorales/12puerna.mid
# key before = A minor
# key after  =  A minor
# Reading file №8; /content/drive/My Drive/Examination/MIDI/chorales/06christ.mid
# key before = F major
# key after  =  C major
# Reading file №9; /content/drive/My Drive/Examination/MIDI/chorales/11jesu.mid
# key before = C major
# key after  =  C major
# Reading file №10; /content/drive/My Drive/Examination/MIDI/chorales/08freuet.mid
# key before = F minor
# key after  =  A minor
# Reading file №11; /content/drive/My Drive/Examination/MIDI/chorales/05anwass.mid
# key before = G major
# key after  =  C major
# Reading file №12; /content/drive/My Drive/Examination/MIDI/chorales/07nunlob.mid
# key before = A major
# key after  =  C major
# Reading file №13; /content/drive/My Drive/Examination/MIDI/chorales/13allein.mid
# key before = A minor
# key after  =  A minor
# Reading file №14; /content/drive/My Drive/Examination/MIDI/chorales/15christ.mid
# key before = D minor
# key after  =  A minor
# Reading file №15; /content/drive/My Drive/Examination/MIDI/chorales/14oherre.mid
# key before = G major
# key after  =  C major
# Reading file №16; /content/drive/My Drive/Examination/MIDI/chorales/chor016.mid
# key before = B minor
# key after  =  A minor
# Reading file №17; /content/drive/My Drive/Examination/MIDI/chorales/chor017.mid
# key before = E minor
# key after  =  A minor
# Reading file №18; /content/drive/My Drive/Examination/MIDI/chorales/chor020.mid
# key before = B minor
# key after  =  A minor
# Reading file №19; /content/drive/My Drive/Examination/MIDI/chorales/chor021.mid
# key before = A minor
# key after  =  A minor
# Reading file №20; /content/drive/My Drive/Examination/MIDI/chorales/chor022.mid
# key before = E- major
# key after  =  C major
# Reading file №21; /content/drive/My Drive/Examination/MIDI/chorales/chor023.mid
# key before = A minor
# key after  =  A minor
# Reading file №22; /content/drive/My Drive/Examination/MIDI/chorales/chor024.mid
# key before = D major
# key after  =  C major
# Reading file №23; /content/drive/My Drive/Examination/MIDI/chorales/chor025.mid
# key before = F minor
# key after  =  A minor
# Reading file №24; /content/drive/My Drive/Examination/MIDI/chorales/chor026.mid
# key before = F major
# key after  =  C major
# Reading file №25; /content/drive/My Drive/Examination/MIDI/chorales/chor027.mid
# key before = B- major
# key after  =  C major
# Reading file №26; /content/drive/My Drive/Examination/MIDI/chorales/chor028.mid
# key before = B minor
# key after  =  A minor
# Reading file №27; /content/drive/My Drive/Examination/MIDI/chorales/chor029.mid
# key before = G major
# key after  =  C major
# Reading file №28; /content/drive/My Drive/Examination/MIDI/chorales/chor030.mid
# key before = E minor
# key after  =  A minor

# %%
print(chorales[0])
# Out:
# [[0, 67, 1000, 1, 64], [0, 64, 1000, 1, 64], [0, 60, 1000, 1, 64], [0, 48, 1000, 1, 64], [1000, 67, 1000, 1, 64], [1000, 62, 500, 1, 64], [1000, 62, 1000, 1, 64], [1000, 47, 1000, 1, 64], [1500, 64, 500, 1, 64], [2000, 67, 1000, 1, 64], [2000, 65, 1000, 1, 64], [2000, 60, 500, 1, 64], [2000, 43, 1000, 1, 64], [2500, 59, 500, 1, 64], [3000, 67, 1000, 1, 64], [3000, 64, 1000, 1, 64], [3000, 60, 1000, 1, 64], [3000, 48, 1000, 1, 64], [4000, 70, 1000, 1, 64], [4000, 62, 1000, 1, 64], [4000, 53, 500, 1, 64], [4000, 50, 500, 1, 64], [4500, 55, 500, 1, 64], [4500, 52, 500, 1, 64], [5000, 69, 1000, 1, 64], [5000, 60, 500, 1, 64], [5000, 57, 250, 1, 64], [5000, 53, 1000, 1, 64], [5250, 58, 250, 1, 64], [5500, 65, 500, 1, 64], [5500, 60, 1000, 1, 64], [6000, 67, 1000, 1, 64], [6000, 65, 500, 1, 64], [6000, 48, 1000, 1, 64], [6500, 64, 500, 1, 64], [6500, 58, 500, 1, 64], [7000, 65, 1000, 1, 64], [7000, 60, 1000, 1, 64], [7000, 57, 1000, 1, 64], [7000, 41, 1000, 1, 64], [8000, 67, 1000, 1, 64], [8000, 62, 1000, 1, 64], [8000, 55, 1000, 1, 64], [8000, 47, 1000, 1, 64], [9000, 64, 1000, 1, 64], [9000, 60, 1000, 1, 64], [9000, 55, 1000, 1, 64], [9000, 48, 500, 1, 64], [9500, 50, 500, 1, 64], [10000, 60, 500, 1, 64], [10000, 60, 500, 1, 64], [10000, 55, 500, 1, 64], [10000, 52, 1000, 1, 64], [10500, 62, 500, 1, 64], [10500, 59, 500, 1, 64], [10500, 53, 500, 1, 64], [11000, 64, 1000, 1, 64], [11000, 60, 1000, 1, 64], [11000, 52, 1000, 1, 64], [11000, 45, 1000, 1, 64], [12000, 66, 1000, 1, 64], [12000, 57, 1000, 1, 64], [12000, 50, 1000, 1, 64], [12000, 50, 500, 1, 64], [12500, 48, 500, 1, 64], [13000, 67, 1000, 1, 64], [13000, 62, 500, 1, 64], [13000, 50, 500, 1, 64], [13000, 47, 500, 1, 64], [13500, 60, 250, 1, 64], [13500, 55, 1000, 1, 64], [13500, 45, 250, 1, 64], [13750, 59, 250, 1, 64], [13750, 43, 250, 1, 64], [14000, 69, 1000, 1, 64], [14000, 60, 1000, 1, 64], [14000, 50, 1000, 1, 64], [14500, 54, 500, 1, 64], [15000, 67, 1000, 1, 64], [15000, 59, 1000, 1, 64], [15000, 50, 1000, 1, 64], [15000, 43, 1000, 1, 64], [16000, 67, 1000, 1, 64], [16000, 64, 1000, 1, 64], [16000, 60, 1000, 1, 64], [16000, 48, 1000, 1, 64], [17000, 67, 1000, 1, 64], [17000, 62, 500, 1, 64], [17000, 62, 1000, 1, 64], [17000, 47, 1000, 1, 64], [17500, 64, 500, 1, 64], [18000, 67, 1000, 1, 64], [18000, 65, 1000, 1, 64], [18000, 60, 500, 1, 64], [18000, 43, 1000, 1, 64], [18500, 59, 500, 1, 64], [19000, 67, 1000, 1, 64], [19000, 64, 1000, 1, 64], [19000, 60, 1000, 1, 64], [19000, 48, 1000, 1, 64], [20000, 70, 1000, 1, 64], [20000, 62, 1000, 1, 64], [20000, 53, 500, 1, 64], [20000, 50, 500, 1, 64], [20500, 55, 500, 1, 64], [20500, 52, 500, 1, 64], [21000, 69, 1000, 1, 64], [21000, 60, 500, 1, 64], [21000, 57, 250, 1, 64], [21000, 53, 1000, 1, 64], [21250, 58, 250, 1, 64], [21500, 65, 500, 1, 64], [21500, 60, 1000, 1, 64], [22000, 67, 1000, 1, 64], [22000, 65, 500, 1, 64], [22000, 48, 1000, 1, 64], [22500, 64, 500, 1, 64], [22500, 58, 500, 1, 64], [23000, 65, 1000, 1, 64], [23000, 60, 1000, 1, 64], [23000, 57, 1000, 1, 64], [23000, 41, 1000, 1, 64], [24000, 67, 1000, 1, 64], [24000, 62, 1000, 1, 64], [24000, 55, 1000, 1, 64], [24000, 47, 1000, 1, 64], [25000, 64, 1000, 1, 64], [25000, 60, 1000, 1, 64], [25000, 55, 1000, 1, 64], [25000, 48, 500, 1, 64], [25500, 50, 500, 1, 64], [26000, 60, 500, 1, 64], [26000, 60, 500, 1, 64], [26000, 55, 500, 1, 64], [26000, 52, 1000, 1, 64], [26500, 62, 500, 1, 64], [26500, 59, 500, 1, 64], [26500, 53, 500, 1, 64], [27000, 64, 1000, 1, 64], [27000, 60, 1000, 1, 64], [27000, 52, 1000, 1, 64], [27000, 45, 1000, 1, 64], [28000, 66, 1000, 1, 64], [28000, 57, 1000, 1, 64], [28000, 50, 1000, 1, 64], [28000, 50, 500, 1, 64], [28500, 48, 500, 1, 64], [29000, 67, 1000, 1, 64], [29000, 62, 500, 1, 64], [29000, 50, 500, 1, 64], [29000, 47, 500, 1, 64], [29500, 60, 250, 1, 64], [29500, 55, 1000, 1, 64], [29500, 45, 250, 1, 64], [29750, 59, 250, 1, 64], [29750, 43, 250, 1, 64], [30000, 69, 1000, 1, 64], [30000, 60, 1000, 1, 64], [30000, 50, 1000, ...

# %% [markdown]
# Для каждого хорала выполняется SPEAC-анализ, после чего в каждое событие каждого хорала добавляется 3 SPEAC-символа: foreground, middleground, background.

# %%
meters = []
speac_analyzes = []

for i in range(1, len(chorales) + 1):
  events = chorales[i - 1]

  meter = 3
  while meter < 21:
      try:
        result = get_note_and_speac(events, meter)
        speac_analyzes.append(result)
        print("file №", i, "; meter = ", meter, "; result = ", result)
        meters.append(meter)
        break

      except Exception as e:
        meter += 1
      pass
  print("------------------")
# Out:
# file № 1 ; meter =  3 ; result =  [[0, 48, 1000, 1, 64, 'statement', 'preparation', 'statement'], [0, 60, 1000, 1, 64, 'statement', 'preparation', 'statement'], [0, 64, 1000, 1, 64, 'statement', 'preparation', 'statement'], [0, 67, 1000, 1, 64, 'statement', 'preparation', 'statement'], [1000, 47, 500, 1, 64, 'extension', 'preparation', 'statement'], [1000, 62, 500, 1, 64, 'extension', 'preparation', 'statement'], [1000, 62, 500, 1, 64, 'extension', 'preparation', 'statement'], [1000, 67, 500, 1, 64, 'extension', 'preparation', 'statement'], [1500, 47, 500, 1, 64, 'extension', 'preparation', 'statement'], [1500, 62, 500, 1, 64, 'extension', 'preparation', 'statement'], [1500, 64, 500, 1, 64, 'extension', 'preparation', 'statement'], [1500, 67, 500, 1, 64, 'extension', 'preparation', 'statement'], [2000, 43, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2000, 60, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2000, 65, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2000, 67, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2500, 43, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2500, 59, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2500, 65, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2500, 67, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [3000, 48, 1000, 1, 64, 'statement', 'preparation', 'statement'], [3000, 60, 1000, 1, 64, 'statement', 'preparation', 'statement'], [3000, 64, 1000, 1, 64, 'statement', 'preparation', 'statement'], [3000, 67, 1000, 1, 64, 'statement', 'preparation', 'statement'], [4000, 50, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4000, 53, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4000, 62, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4000, 70, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4500, 52, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4500, 55, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4500, 62, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4500, 70, 500, 1, 64, 'preparation', 'preparation', 'statement'], [5000, 53, 250, 1, 64, 'extension', 'preparation', 'statement'], [5000, 57, 250, 1, 64, 'extension', 'preparation', 'statement'], [5000, 60, 250, 1, 64, 'extension', 'preparation', 'statement'], [5000, 69, 250, 1, 64, 'extension', 'preparation', 'statement'], [5250, 53, 250, 1, 64, 'extension', 'preparation', 'statement'], [5250, 58, 250, 1, 64, 'extension', 'preparation', 'statement'], [5250, 60, 250, 1, 64, 'extension', 'preparation', 'statement'], [5250, 69, 250, 1, 64, 'extension', 'preparation', 'statement'], [5500, 53, 500, 1, 64, 'extension', 'preparation', 'statement'], [5500, 60, 500, 1, 64, 'extension', 'preparation', 'statement'], [5500, 65, 500, 1, 64, 'extension', 'preparation', 'statement'], [5500, 69, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 48, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 60, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 65, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 67, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 48, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 58, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 64, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 67, 500, 1, 64, 'extension', 'preparation', 'statement'], [7000, 41, 1000, 1, 64, 'statement', 'preparation', 'statement'], [7000, 57, 1000, 1, 64, 'statement', 'preparation', 'statement'], [7000, 60, 1000, 1, 64, 'statement', 'preparation', 'statement'], [7000, 65, 1000, 1, 64, 'statement', 'preparation', 'statement'], [8000, 47, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [8000, 55, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [8000, 62, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [8000, 67, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [9000, 48, 500, 1, 64, 'consequen ...
# ------------------
# file № 2 ; meter =  3 ; result =  [[0, 50, 2000, 1, 64, 'antecedent', 'preparation', 'statement'], [0, 56, 2000, 1, 64, 'antecedent', 'preparation', 'statement'], [0, 64, 2000, 1, 64, 'antecedent', 'preparation', 'statement'], [0, 71, 2000, 1, 64, 'antecedent', 'preparation', 'statement'], [2000, 48, 1000, 1, 64, 'statement', 'preparation', 'statement'], [2000, 57, 1000, 1, 64, 'statement', 'preparation', 'statement'], [2000, 64, 1000, 1, 64, 'statement', 'preparation', 'statement'], [2000, 64, 1000, 1, 64, 'statement', 'preparation', 'statement'], [3000, 47, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [3000, 62, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [3000, 68, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [3000, 71, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [4000, 45, 1000, 1, 64, 'extension', 'preparation', 'statement'], [4000, 64, 1000, 1, 64, 'extension', 'preparation', 'statement'], [4000, 69, 1000, 1, 64, 'extension', 'preparation', 'statement'], [4000, 72, 1000, 1, 64, 'extension', 'preparation', 'statement'], [5000, 47, 500, 1, 64, 'statement', 'preparation', 'statement'], [5000, 62, 500, 1, 64, 'statement', 'preparation', 'statement'], [5000, 67, 500, 1, 64, 'statement', 'preparation', 'statement'], [5000, 71, 500, 1, 64, 'statement', 'preparation', 'statement'], [5500, 47, 500, 1, 64, 'statement', 'preparation', 'statement'], [5500, 62, 500, 1, 64, 'statement', 'preparation', 'statement'], [5500, 66, 500, 1, 64, 'statement', 'preparation', 'statement'], [5500, 69, 500, 1, 64, 'statement', 'preparation', 'statement'], [6000, 48, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 64, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 64, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 67, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 47, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 62, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 64, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 67, 500, 1, 64, 'extension', 'preparation', 'statement'], [7000, 45, 1000, 1, 64, 'extension', 'preparation', 'statement'], [7000, 60, 1000, 1, 64, 'extension', 'preparation', 'statement'], [7000, 66, 1000, 1, 64, 'extension', 'preparation', 'statement'], [7000, 69, 1000, 1, 64, 'extension', 'preparation', 'statement'], [8000, 52, 2000, 1, 64, 'preparation', 'preparation', 'statement'], [8000, 59, 2000, 1, 64, 'preparation', 'preparation', 'statement'], [8000, 68, 2000, 1, 64, 'preparation', 'preparation', 'statement'], [8000, 71, 2000, 1, 64, 'preparation', 'preparation', 'statement'], [10000, 52, 2000, 1, 64, 'extension', 'preparation', 'statement'], [10000, 64, 2000, 1, 64, 'extension', 'preparation', 'statement'], [10000, 68, 2000, 1, 64, 'extension', 'preparation', 'statement'], [10000, 71, 2000, 1, 64, 'extension', 'preparation', 'statement'], [12000, 57, 1000, 1, 64, 'statement', 'preparation', 'statement'], [12000, 64, 1000, 1, 64, 'statement', 'preparation', 'statement'], [12000, 69, 1000, 1, 64, 'statement', 'preparation', 'statement'], [12000, 72, 1000, 1, 64, 'statement', 'preparation', 'statement'], [13000, 55, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [13000, 65, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [13000, 71, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [13000, 74, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [13500, 53, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [13500, 65, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [13500, 71, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [13500, 74, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [14000, 52, 500, 1, 64, 'statement', 'preparation', 'statement'], [14000, 67, 500, 1, 64, 'statement', 'preparation', 'statement'], [14000, 72, 500, 1, 64, 'statement', 'preparation', 'statement'], [14000, 72, 500, 1, 64, 'statement', 'preparation', 'statement' ...
# ------------------
# file № 3 ; meter =  3 ; result =  [[0, 48, 1000, 1, 64, 'statement', 'statement', 'statement'], [0, 64, 1000, 1, 64, 'statement', 'statement', 'statement'], [0, 67, 1000, 1, 64, 'statement', 'statement', 'statement'], [0, 72, 1000, 1, 64, 'statement', 'statement', 'statement'], [1000, 60, 1000, 1, 64, 'extension', 'statement', 'statement'], [1000, 64, 1000, 1, 64, 'extension', 'statement', 'statement'], [1000, 67, 1000, 1, 64, 'extension', 'statement', 'statement'], [1000, 72, 1000, 1, 64, 'extension', 'statement', 'statement'], [2000, 57, 500, 1, 64, 'extension', 'statement', 'statement'], [2000, 65, 500, 1, 64, 'extension', 'statement', 'statement'], [2000, 69, 500, 1, 64, 'extension', 'statement', 'statement'], [2000, 72, 500, 1, 64, 'extension', 'statement', 'statement'], [2500, 57, 500, 1, 64, 'extension', 'statement', 'statement'], [2500, 64, 500, 1, 64, 'extension', 'statement', 'statement'], [2500, 69, 500, 1, 64, 'extension', 'statement', 'statement'], [2500, 72, 500, 1, 64, 'extension', 'statement', 'statement'], [3000, 59, 1000, 1, 64, 'antecedent', 'statement', 'statement'], [3000, 62, 1000, 1, 64, 'antecedent', 'statement', 'statement'], [3000, 67, 1000, 1, 64, 'antecedent', 'statement', 'statement'], [3000, 79, 1000, 1, 64, 'antecedent', 'statement', 'statement'], [4000, 60, 1000, 1, 64, 'consequent', 'statement', 'statement'], [4000, 60, 1000, 1, 64, 'consequent', 'statement', 'statement'], [4000, 67, 1000, 1, 64, 'consequent', 'statement', 'statement'], [4000, 76, 1000, 1, 64, 'consequent', 'statement', 'statement'], [5000, 55, 500, 1, 64, 'consequent', 'statement', 'statement'], [5000, 59, 500, 1, 64, 'consequent', 'statement', 'statement'], [5000, 67, 500, 1, 64, 'consequent', 'statement', 'statement'], [5000, 76, 500, 1, 64, 'consequent', 'statement', 'statement'], [5500, 55, 500, 1, 64, 'consequent', 'statement', 'statement'], [5500, 59, 500, 1, 64, 'consequent', 'statement', 'statement'], [5500, 67, 500, 1, 64, 'consequent', 'statement', 'statement'], [5500, 74, 500, 1, 64, 'consequent', 'statement', 'statement'], [6000, 57, 1000, 1, 64, 'antecedent', 'statement', 'statement'], [6000, 60, 1000, 1, 64, 'antecedent', 'statement', 'statement'], [6000, 64, 1000, 1, 64, 'antecedent', 'statement', 'statement'], [6000, 72, 1000, 1, 64, 'antecedent', 'statement', 'statement'], [7000, 53, 500, 1, 64, 'statement', 'statement', 'statement'], [7000, 65, 500, 1, 64, 'statement', 'statement', 'statement'], [7000, 69, 500, 1, 64, 'statement', 'statement', 'statement'], [7000, 72, 500, 1, 64, 'statement', 'statement', 'statement'], [7500, 53, 500, 1, 64, 'statement', 'statement', 'statement'], [7500, 64, 500, 1, 64, 'statement', 'statement', 'statement'], [7500, 67, 500, 1, 64, 'statement', 'statement', 'statement'], [7500, 72, 500, 1, 64, 'statement', 'statement', 'statement'], [8000, 52, 500, 1, 64, 'statement', 'statement', 'statement'], [8000, 65, 500, 1, 64, 'statement', 'statement', 'statement'], [8000, 69, 500, 1, 64, 'statement', 'statement', 'statement'], [8000, 72, 500, 1, 64, 'statement', 'statement', 'statement'], [8500, 50, 500, 1, 64, 'statement', 'statement', 'statement'], [8500, 65, 500, 1, 64, 'statement', 'statement', 'statement'], [8500, 71, 500, 1, 64, 'statement', 'statement', 'statement'], [8500, 74, 500, 1, 64, 'statement', 'statement', 'statement'], [9000, 48, 1000, 1, 64, 'statement', 'extension', 'statement'], [9000, 67, 1000, 1, 64, 'statement', 'extension', 'statement'], [9000, 72, 1000, 1, 64, 'statement', 'extension', 'statement'], [9000, 76, 1000, 1, 64, 'statement', 'extension', 'statement'], [10000, 55, 2000, 1, 64, 'preparation', 'preparation', 'statement'], [10000, 67, 2000, 1, 64, 'preparation', 'preparation', 'statement'], [10000, 71, 2000, 1, 64, 'preparation', 'preparation', 'statement'], [10000, 74, 2000, 1, 64, 'preparation', 'preparation', 'statement'], [12000, 48, 1000, 1, 64, 'extension', 'preparation', 'statement'], [12000, 67, 1000, 1, 64, 'extension', 'preparation', 'statemen ...
# ------------------
# file № 4 ; meter =  3 ; result =  [[0, 52, 1000, 1, 64, 'statement', 'preparation', 'statement'], [0, 64, 1000, 1, 64, 'statement', 'preparation', 'statement'], [0, 68, 1000, 1, 64, 'statement', 'preparation', 'statement'], [0, 71, 1000, 1, 64, 'statement', 'preparation', 'statement'], [1000, 57, 1000, 1, 64, 'extension', 'preparation', 'statement'], [1000, 64, 1000, 1, 64, 'extension', 'preparation', 'statement'], [1000, 69, 1000, 1, 64, 'extension', 'preparation', 'statement'], [1000, 72, 1000, 1, 64, 'extension', 'preparation', 'statement'], [2000, 59, 1000, 1, 64, 'extension', 'preparation', 'statement'], [2000, 62, 1000, 1, 64, 'extension', 'preparation', 'statement'], [2000, 68, 1000, 1, 64, 'extension', 'preparation', 'statement'], [2000, 71, 1000, 1, 64, 'extension', 'preparation', 'statement'], [3000, 60, 1000, 1, 64, 'extension', 'preparation', 'statement'], [3000, 64, 1000, 1, 64, 'extension', 'preparation', 'statement'], [3000, 69, 1000, 1, 64, 'extension', 'preparation', 'statement'], [3000, 69, 1000, 1, 64, 'extension', 'preparation', 'statement'], [4000, 59, 500, 1, 64, 'extension', 'preparation', 'statement'], [4000, 62, 500, 1, 64, 'extension', 'preparation', 'statement'], [4000, 68, 500, 1, 64, 'extension', 'preparation', 'statement'], [4000, 76, 500, 1, 64, 'extension', 'preparation', 'statement'], [4500, 57, 500, 1, 64, 'extension', 'preparation', 'statement'], [4500, 60, 500, 1, 64, 'extension', 'preparation', 'statement'], [4500, 69, 500, 1, 64, 'extension', 'preparation', 'statement'], [4500, 76, 500, 1, 64, 'extension', 'preparation', 'statement'], [5000, 56, 500, 1, 64, 'extension', 'preparation', 'statement'], [5000, 59, 500, 1, 64, 'extension', 'preparation', 'statement'], [5000, 71, 500, 1, 64, 'extension', 'preparation', 'statement'], [5000, 76, 500, 1, 64, 'extension', 'preparation', 'statement'], [5500, 56, 500, 1, 64, 'extension', 'preparation', 'statement'], [5500, 59, 500, 1, 64, 'extension', 'preparation', 'statement'], [5500, 71, 500, 1, 64, 'extension', 'preparation', 'statement'], [5500, 74, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 57, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 60, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 64, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 72, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 57, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 62, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 66, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 72, 500, 1, 64, 'extension', 'preparation', 'statement'], [7000, 52, 1000, 1, 64, 'extension', 'preparation', 'statement'], [7000, 64, 1000, 1, 64, 'extension', 'preparation', 'statement'], [7000, 68, 1000, 1, 64, 'extension', 'preparation', 'statement'], [7000, 71, 1000, 1, 64, 'extension', 'preparation', 'statement'], [8000, 47, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [8000, 65, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [8000, 68, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [8000, 74, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [9000, 48, 500, 1, 64, 'statement', 'preparation', 'statement'], [9000, 64, 500, 1, 64, 'statement', 'preparation', 'statement'], [9000, 69, 500, 1, 64, 'statement', 'preparation', 'statement'], [9000, 72, 500, 1, 64, 'statement', 'preparation', 'statement'], [9500, 50, 500, 1, 64, 'statement', 'preparation', 'statement'], [9500, 64, 500, 1, 64, 'statement', 'preparation', 'statement'], [9500, 69, 500, 1, 64, 'statement', 'preparation', 'statement'], [9500, 72, 500, 1, 64, 'statement', 'preparation', 'statement'], [10000, 52, 500, 1, 64, 'extension', 'preparation', 'statement'], [10000, 64, 500, 1, 64, 'extension', 'preparation', 'statement'], [10000, 68, 500, 1, 64, 'extension', 'preparation', 'statement'], [10000, 71, 500, 1, 64, 'extension', 'preparation', 'statement'], [10500, 52, 500, 1, 64, 'extension', 'prepara ...
# ------------------
# file № 5 ; meter =  3 ; result =  [[0, 60, 500, 1, 64, 'statement', 'preparation', 'statement'], [0, 64, 500, 1, 64, 'statement', 'preparation', 'statement'], [0, 67, 500, 1, 64, 'statement', 'preparation', 'statement'], [0, 72, 500, 1, 64, 'statement', 'preparation', 'statement'], [500, 59, 500, 1, 64, 'statement', 'preparation', 'statement'], [500, 64, 500, 1, 64, 'statement', 'preparation', 'statement'], [500, 67, 500, 1, 64, 'statement', 'preparation', 'statement'], [500, 72, 500, 1, 64, 'statement', 'preparation', 'statement'], [1000, 57, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [1000, 64, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [1000, 69, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [1000, 72, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [2000, 52, 500, 1, 64, 'extension', 'preparation', 'statement'], [2000, 64, 500, 1, 64, 'extension', 'preparation', 'statement'], [2000, 67, 500, 1, 64, 'extension', 'preparation', 'statement'], [2000, 72, 500, 1, 64, 'extension', 'preparation', 'statement'], [2500, 52, 500, 1, 64, 'extension', 'preparation', 'statement'], [2500, 62, 500, 1, 64, 'extension', 'preparation', 'statement'], [2500, 67, 500, 1, 64, 'extension', 'preparation', 'statement'], [2500, 72, 500, 1, 64, 'extension', 'preparation', 'statement'], [3000, 53, 500, 1, 64, 'statement', 'preparation', 'statement'], [3000, 60, 500, 1, 64, 'statement', 'preparation', 'statement'], [3000, 69, 500, 1, 64, 'statement', 'preparation', 'statement'], [3000, 72, 500, 1, 64, 'statement', 'preparation', 'statement'], [3500, 53, 500, 1, 64, 'statement', 'preparation', 'statement'], [3500, 59, 500, 1, 64, 'statement', 'preparation', 'statement'], [3500, 69, 500, 1, 64, 'statement', 'preparation', 'statement'], [3500, 72, 500, 1, 64, 'statement', 'preparation', 'statement'], [4000, 54, 1000, 1, 64, 'extension', 'preparation', 'statement'], [4000, 57, 1000, 1, 64, 'extension', 'preparation', 'statement'], [4000, 69, 1000, 1, 64, 'extension', 'preparation', 'statement'], [4000, 74, 1000, 1, 64, 'extension', 'preparation', 'statement'], [5000, 55, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [5000, 62, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [5000, 67, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [5000, 70, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [6000, 50, 500, 1, 64, 'preparation', 'preparation', 'statement'], [6000, 62, 500, 1, 64, 'preparation', 'preparation', 'statement'], [6000, 66, 500, 1, 64, 'preparation', 'preparation', 'statement'], [6000, 69, 500, 1, 64, 'preparation', 'preparation', 'statement'], [6500, 50, 500, 1, 64, 'preparation', 'preparation', 'statement'], [6500, 60, 500, 1, 64, 'preparation', 'preparation', 'statement'], [6500, 66, 500, 1, 64, 'preparation', 'preparation', 'statement'], [6500, 69, 500, 1, 64, 'preparation', 'preparation', 'statement'], [7000, 43, 1000, 1, 64, 'extension', 'preparation', 'statement'], [7000, 59, 1000, 1, 64, 'extension', 'preparation', 'statement'], [7000, 62, 1000, 1, 64, 'extension', 'preparation', 'statement'], [7000, 67, 1000, 1, 64, 'extension', 'preparation', 'statement'], [8000, 55, 1000, 1, 64, 'extension', 'preparation', 'statement'], [8000, 67, 1000, 1, 64, 'extension', 'preparation', 'statement'], [8000, 71, 1000, 1, 64, 'extension', 'preparation', 'statement'], [8000, 74, 1000, 1, 64, 'extension', 'preparation', 'statement'], [9000, 60, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [9000, 67, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [9000, 72, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [9000, 76, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [10000, 62, 500, 1, 64, 'extension', 'preparation', 'statement'], [10000, 66, 500, 1, 64, 'extension', 'preparation', 'statement'], [10000, 71, 500, 1, 64, 'extension', 'preparation', 'statement'], [10000, 74, 500, 1, 64, 'extension', 'preparation', 'statement'], [10500, 62, 5 ...
# ------------------
# file № 6 ; meter =  3 ; result =  [[0, 60, 500, 1, 64, 'statement', 'statement', 'statement'], [0, 64, 500, 1, 64, 'statement', 'statement', 'statement'], [0, 67, 500, 1, 64, 'statement', 'statement', 'statement'], [0, 72, 500, 1, 64, 'statement', 'statement', 'statement'], [500, 59, 500, 1, 64, 'statement', 'statement', 'statement'], [500, 64, 500, 1, 64, 'statement', 'statement', 'statement'], [500, 67, 500, 1, 64, 'statement', 'statement', 'statement'], [500, 72, 500, 1, 64, 'statement', 'statement', 'statement'], [1000, 57, 500, 1, 64, 'extension', 'statement', 'statement'], [1000, 64, 500, 1, 64, 'extension', 'statement', 'statement'], [1000, 69, 500, 1, 64, 'extension', 'statement', 'statement'], [1000, 72, 500, 1, 64, 'extension', 'statement', 'statement'], [1500, 57, 500, 1, 64, 'extension', 'statement', 'statement'], [1500, 65, 500, 1, 64, 'extension', 'statement', 'statement'], [1500, 69, 500, 1, 64, 'extension', 'statement', 'statement'], [1500, 72, 500, 1, 64, 'extension', 'statement', 'statement'], [2000, 55, 500, 1, 64, 'extension', 'statement', 'statement'], [2000, 65, 500, 1, 64, 'extension', 'statement', 'statement'], [2000, 71, 500, 1, 64, 'extension', 'statement', 'statement'], [2000, 74, 500, 1, 64, 'extension', 'statement', 'statement'], [2500, 55, 500, 1, 64, 'extension', 'statement', 'statement'], [2500, 67, 500, 1, 64, 'extension', 'statement', 'statement'], [2500, 71, 500, 1, 64, 'extension', 'statement', 'statement'], [2500, 74, 500, 1, 64, 'extension', 'statement', 'statement'], [3000, 60, 500, 1, 64, 'statement', 'preparation', 'statement'], [3000, 64, 500, 1, 64, 'statement', 'preparation', 'statement'], [3000, 67, 500, 1, 64, 'statement', 'preparation', 'statement'], [3000, 76, 500, 1, 64, 'statement', 'preparation', 'statement'], [3500, 60, 500, 1, 64, 'statement', 'preparation', 'statement'], [3500, 62, 500, 1, 64, 'statement', 'preparation', 'statement'], [3500, 69, 500, 1, 64, 'statement', 'preparation', 'statement'], [3500, 78, 500, 1, 64, 'statement', 'preparation', 'statement'], [4000, 59, 500, 1, 64, 'extension', 'preparation', 'statement'], [4000, 62, 500, 1, 64, 'extension', 'preparation', 'statement'], [4000, 71, 500, 1, 64, 'extension', 'preparation', 'statement'], [4000, 79, 500, 1, 64, 'extension', 'preparation', 'statement'], [4500, 60, 500, 1, 64, 'extension', 'preparation', 'statement'], [4500, 62, 500, 1, 64, 'extension', 'preparation', 'statement'], [4500, 71, 500, 1, 64, 'extension', 'preparation', 'statement'], [4500, 79, 500, 1, 64, 'extension', 'preparation', 'statement'], [5000, 62, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [5000, 62, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [5000, 69, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [5000, 79, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [5500, 62, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [5500, 62, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [5500, 71, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [5500, 79, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [6000, 50, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [6000, 62, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [6000, 72, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [6000, 78, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [7000, 55, 1000, 1, 64, 'extension', 'preparation', 'statement'], [7000, 62, 1000, 1, 64, 'extension', 'preparation', 'statement'], [7000, 71, 1000, 1, 64, 'extension', 'preparation', 'statement'], [7000, 79, 1000, 1, 64, 'extension', 'preparation', 'statement'], [8000, 56, 500, 1, 64, 'extension', 'preparation', 'statement'], [8000, 64, 500, 1, 64, 'extension', 'preparation', 'statement'], [8000, 71, 500, 1, 64, 'extension', 'preparation', 'statement'], [8000, 76, 500, 1, 64, 'extension', 'preparation', 'statement'], [8500, 56, 500, 1, 64, 'extension', 'preparation', 'statement'], [8500, 62, 500, 1, 64, 'extension', 'pre ...
# ------------------
# file № 7 ; meter =  4 ; result =  [[0, 45, 1000, 1, 64, 'statement', 'preparation', 'statement'], [0, 60, 1000, 1, 64, 'statement', 'preparation', 'statement'], [0, 64, 1000, 1, 64, 'statement', 'preparation', 'statement'], [0, 69, 1000, 1, 64, 'statement', 'preparation', 'statement'], [1000, 57, 1000, 1, 64, 'extension', 'preparation', 'statement'], [1000, 60, 1000, 1, 64, 'extension', 'preparation', 'statement'], [1000, 64, 1000, 1, 64, 'extension', 'preparation', 'statement'], [1000, 69, 1000, 1, 64, 'extension', 'preparation', 'statement'], [2000, 55, 1000, 1, 64, 'extension', 'preparation', 'statement'], [2000, 60, 1000, 1, 64, 'extension', 'preparation', 'statement'], [2000, 64, 1000, 1, 64, 'extension', 'preparation', 'statement'], [2000, 69, 1000, 1, 64, 'extension', 'preparation', 'statement'], [3000, 54, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [3000, 62, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [3000, 69, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [3000, 69, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [4000, 55, 1000, 1, 64, 'extension', 'preparation', 'statement'], [4000, 62, 1000, 1, 64, 'extension', 'preparation', 'statement'], [4000, 67, 1000, 1, 64, 'extension', 'preparation', 'statement'], [4000, 71, 1000, 1, 64, 'extension', 'preparation', 'statement'], [5000, 50, 1000, 1, 64, 'extension', 'preparation', 'statement'], [5000, 62, 1000, 1, 64, 'extension', 'preparation', 'statement'], [5000, 67, 1000, 1, 64, 'extension', 'preparation', 'statement'], [5000, 71, 1000, 1, 64, 'extension', 'preparation', 'statement'], [6000, 53, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [6000, 62, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [6000, 67, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [6000, 71, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [7000, 52, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [7000, 60, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [7000, 67, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [7000, 72, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [8000, 48, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [8000, 64, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [8000, 67, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [8000, 71, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [9000, 53, 1000, 1, 64, 'extension', 'preparation', 'statement'], [9000, 60, 1000, 1, 64, 'extension', 'preparation', 'statement'], [9000, 65, 1000, 1, 64, 'extension', 'preparation', 'statement'], [9000, 69, 1000, 1, 64, 'extension', 'preparation', 'statement'], [10000, 48, 3000, 1, 64, 'extension', 'preparation', 'statement'], [10000, 60, 3000, 1, 64, 'extension', 'preparation', 'statement'], [10000, 64, 3000, 1, 64, 'extension', 'preparation', 'statement'], [10000, 67, 3000, 1, 64, 'extension', 'preparation', 'statement'], [13000, 48, 1000, 1, 64, 'statement', 'preparation', 'statement'], [13000, 64, 1000, 1, 64, 'statement', 'preparation', 'statement'], [13000, 67, 1000, 1, 64, 'statement', 'preparation', 'statement'], [13000, 72, 1000, 1, 64, 'statement', 'preparation', 'statement'], [14000, 60, 1000, 1, 64, 'statement', 'preparation', 'statement'], [14000, 64, 1000, 1, 64, 'statement', 'preparation', 'statement'], [14000, 67, 1000, 1, 64, 'statement', 'preparation', 'statement'], [14000, 72, 1000, 1, 64, 'statement', 'preparation', 'statement'], [15000, 59, 1000, 1, 64, 'extension', 'preparation', 'statement'], [15000, 64, 1000, 1, 64, 'extension', 'preparation', 'statement'], [15000, 68, 1000, 1, 64, 'extension', 'preparation', 'statement'], [15000, 74, 1000, 1, 64, 'extension', 'preparation', 'statement'], [16000, 57, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [16000, 64, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [16000, 69, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [16000, 72, 1000, 1, 64, 'prep ...
# ------------------
# file № 8 ; meter =  3 ; result =  [[0, 36, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [0, 52, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [0, 55, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [0, 60, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [1000, 48, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [1000, 55, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [1000, 60, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [1000, 64, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [2000, 47, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [2000, 55, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [2000, 62, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [2000, 62, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [3000, 46, 1000, 1, 64, 'antecedent', 'antecedent', 'statement'], [3000, 55, 1000, 1, 64, 'antecedent', 'antecedent', 'statement'], [3000, 60, 1000, 1, 64, 'antecedent', 'antecedent', 'statement'], [3000, 64, 1000, 1, 64, 'antecedent', 'antecedent', 'statement'], [4000, 45, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [4000, 57, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [4000, 60, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [4000, 65, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [5000, 43, 500, 1, 64, 'extension', 'antecedent', 'statement'], [5000, 50, 500, 1, 64, 'extension', 'antecedent', 'statement'], [5000, 59, 500, 1, 64, 'extension', 'antecedent', 'statement'], [5000, 67, 500, 1, 64, 'extension', 'antecedent', 'statement'], [5500, 45, 500, 1, 64, 'extension', 'antecedent', 'statement'], [5500, 50, 500, 1, 64, 'extension', 'antecedent', 'statement'], [5500, 60, 500, 1, 64, 'extension', 'antecedent', 'statement'], [5500, 67, 500, 1, 64, 'extension', 'antecedent', 'statement'], [6000, 47, 500, 1, 64, 'extension', 'antecedent', 'statement'], [6000, 55, 500, 1, 64, 'extension', 'antecedent', 'statement'], [6000, 62, 500, 1, 64, 'extension', 'antecedent', 'statement'], [6000, 67, 500, 1, 64, 'extension', 'antecedent', 'statement'], [6500, 43, 500, 1, 64, 'extension', 'antecedent', 'statement'], [6500, 55, 500, 1, 64, 'extension', 'antecedent', 'statement'], [6500, 59, 500, 1, 64, 'extension', 'antecedent', 'statement'], [6500, 67, 500, 1, 64, 'extension', 'antecedent', 'statement'], [7000, 48, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [7000, 55, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [7000, 60, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [7000, 64, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [8000, 41, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [8000, 53, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [8000, 60, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [8000, 69, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [9000, 40, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [9000, 55, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [9000, 60, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [9000, 67, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [10000, 38, 500, 1, 64, 'extension', 'antecedent', 'statement'], [10000, 57, 500, 1, 64, 'extension', 'antecedent', 'statement'], [10000, 60, 500, 1, 64, 'extension', 'antecedent', 'statement'], [10000, 65, 500, 1, 64, 'extension', 'antecedent', 'statement'], [10500, 38, 500, 1, 64, 'extension', 'antecedent', 'statement'], [10500, 53, 500, 1, 64, 'extension', 'antecedent', 'statement'], [10500, 59, 500, 1, 64, 'extension', 'antecedent', 'statement'], [10500, 65, 500, 1, 64, 'extension', 'antecedent', 'statement'], [11000, 36, 500, 1, 64, 'preparation', 'consequent', 'statement'], [11000, 55, 500, 1, 64, 'preparation', 'consequent', 'statement'], [11000, 60, 500, 1, 64, 'preparation', 'consequent', 'statement'], [11000, 64, 500, 1, 64, 'preparation', 'consequent', 'statement'], [11500, 40, 500, 1, 64, 'preparation', 'consequent', 'statement'] ...
# ------------------
# file № 9 ; meter =  9 ; result =  [[0, 48, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [0, 60, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [0, 67, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [0, 76, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [1000, 48, 500, 1, 64, 'extension', 'antecedent', 'statement'], [1000, 60, 500, 1, 64, 'extension', 'antecedent', 'statement'], [1000, 67, 500, 1, 64, 'extension', 'antecedent', 'statement'], [1000, 76, 500, 1, 64, 'extension', 'antecedent', 'statement'], [1500, 48, 500, 1, 64, 'extension', 'antecedent', 'statement'], [1500, 62, 500, 1, 64, 'extension', 'antecedent', 'statement'], [1500, 67, 500, 1, 64, 'extension', 'antecedent', 'statement'], [1500, 76, 500, 1, 64, 'extension', 'antecedent', 'statement'], [2000, 60, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [2000, 64, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [2000, 67, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [2000, 72, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [3000, 59, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [3000, 62, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [3000, 67, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [3000, 74, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [4000, 58, 1000, 1, 64, 'antecedent', 'antecedent', 'statement'], [4000, 60, 1000, 1, 64, 'antecedent', 'antecedent', 'statement'], [4000, 67, 1000, 1, 64, 'antecedent', 'antecedent', 'statement'], [4000, 76, 1000, 1, 64, 'antecedent', 'antecedent', 'statement'], [5000, 57, 500, 1, 64, 'statement', 'antecedent', 'statement'], [5000, 60, 500, 1, 64, 'statement', 'antecedent', 'statement'], [5000, 65, 500, 1, 64, 'statement', 'antecedent', 'statement'], [5000, 77, 500, 1, 64, 'statement', 'antecedent', 'statement'], [5500, 57, 500, 1, 64, 'statement', 'antecedent', 'statement'], [5500, 60, 500, 1, 64, 'statement', 'antecedent', 'statement'], [5500, 67, 500, 1, 64, 'statement', 'antecedent', 'statement'], [5500, 77, 500, 1, 64, 'statement', 'antecedent', 'statement'], [6000, 55, 500, 1, 64, 'statement', 'antecedent', 'statement'], [6000, 65, 500, 1, 64, 'statement', 'antecedent', 'statement'], [6000, 69, 500, 1, 64, 'statement', 'antecedent', 'statement'], [6000, 77, 500, 1, 64, 'statement', 'antecedent', 'statement'], [6500, 53, 500, 1, 64, 'statement', 'antecedent', 'statement'], [6500, 65, 500, 1, 64, 'statement', 'antecedent', 'statement'], [6500, 69, 500, 1, 64, 'statement', 'antecedent', 'statement'], [6500, 77, 500, 1, 64, 'statement', 'antecedent', 'statement'], [7000, 58, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [7000, 65, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [7000, 70, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [7000, 74, 1000, 1, 64, 'preparation', 'antecedent', 'statement'], [8000, 54, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [8000, 57, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [8000, 69, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [8000, 74, 1000, 1, 64, 'extension', 'antecedent', 'statement'], [9000, 55, 500, 1, 64, 'extension', 'antecedent', 'statement'], [9000, 59, 500, 1, 64, 'extension', 'antecedent', 'statement'], [9000, 67, 500, 1, 64, 'extension', 'antecedent', 'statement'], [9000, 74, 500, 1, 64, 'extension', 'antecedent', 'statement'], [9500, 53, 500, 1, 64, 'extension', 'antecedent', 'statement'], [9500, 59, 500, 1, 64, 'extension', 'antecedent', 'statement'], [9500, 67, 500, 1, 64, 'extension', 'antecedent', 'statement'], [9500, 74, 500, 1, 64, 'extension', 'antecedent', 'statement'], [10000, 52, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [10000, 60, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [10000, 67, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [10000, 72, 1000, 1, 64, 'statement', 'antecedent', 'statement'], [11000, 53, 500, 1, 64, 'extension', 'antecedent', 'statement'], [11000, 65, 500, 1,  ...
# ------------------
# file № 10 ; meter =  3 ; result =  [[0, 57, 1000, 1, 64, 'statement', 'statement', 'statement'], [0, 60, 1000, 1, 64, 'statement', 'statement', 'statement'], [0, 69, 1000, 1, 64, 'statement', 'statement', 'statement'], [0, 76, 1000, 1, 64, 'statement', 'statement', 'statement'], [1000, 55, 1000, 1, 64, 'antecedent', 'statement', 'statement'], [1000, 61, 1000, 1, 64, 'antecedent', 'statement', 'statement'], [1000, 69, 1000, 1, 64, 'antecedent', 'statement', 'statement'], [1000, 76, 1000, 1, 64, 'antecedent', 'statement', 'statement'], [2000, 53, 500, 1, 64, 'statement', 'statement', 'statement'], [2000, 62, 500, 1, 64, 'statement', 'statement', 'statement'], [2000, 69, 500, 1, 64, 'statement', 'statement', 'statement'], [2000, 74, 500, 1, 64, 'statement', 'statement', 'statement'], [2500, 53, 500, 1, 64, 'statement', 'statement', 'statement'], [2500, 62, 500, 1, 64, 'statement', 'statement', 'statement'], [2500, 68, 500, 1, 64, 'statement', 'statement', 'statement'], [2500, 74, 500, 1, 64, 'statement', 'statement', 'statement'], [3000, 52, 1000, 1, 64, 'extension', 'statement', 'statement'], [3000, 64, 1000, 1, 64, 'extension', 'statement', 'statement'], [3000, 69, 1000, 1, 64, 'extension', 'statement', 'statement'], [3000, 72, 1000, 1, 64, 'extension', 'statement', 'statement'], [4000, 50, 500, 1, 64, 'extension', 'statement', 'statement'], [4000, 65, 500, 1, 64, 'extension', 'statement', 'statement'], [4000, 69, 500, 1, 64, 'extension', 'statement', 'statement'], [4000, 71, 500, 1, 64, 'extension', 'statement', 'statement'], [4500, 50, 500, 1, 64, 'extension', 'statement', 'statement'], [4500, 65, 500, 1, 64, 'extension', 'statement', 'statement'], [4500, 71, 500, 1, 64, 'extension', 'statement', 'statement'], [4500, 71, 500, 1, 64, 'extension', 'statement', 'statement'], [5000, 52, 500, 1, 64, 'extension', 'statement', 'statement'], [5000, 64, 500, 1, 64, 'extension', 'statement', 'statement'], [5000, 68, 500, 1, 64, 'extension', 'statement', 'statement'], [5000, 68, 500, 1, 64, 'extension', 'statement', 'statement'], [5500, 52, 500, 1, 64, 'extension', 'statement', 'statement'], [5500, 62, 500, 1, 64, 'extension', 'statement', 'statement'], [5500, 68, 500, 1, 64, 'extension', 'statement', 'statement'], [5500, 68, 500, 1, 64, 'extension', 'statement', 'statement'], [6000, 45, 1000, 1, 64, 'preparation', 'statement', 'statement'], [6000, 60, 1000, 1, 64, 'preparation', 'statement', 'statement'], [6000, 69, 1000, 1, 64, 'preparation', 'statement', 'statement'], [6000, 69, 1000, 1, 64, 'preparation', 'statement', 'statement'], [7000, 45, 1000, 1, 64, 'extension', 'statement', 'statement'], [7000, 60, 1000, 1, 64, 'extension', 'statement', 'statement'], [7000, 64, 1000, 1, 64, 'extension', 'statement', 'statement'], [7000, 69, 1000, 1, 64, 'extension', 'statement', 'statement'], [8000, 57, 1000, 1, 64, 'extension', 'statement', 'statement'], [8000, 64, 1000, 1, 64, 'extension', 'statement', 'statement'], [8000, 69, 1000, 1, 64, 'extension', 'statement', 'statement'], [8000, 72, 1000, 1, 64, 'extension', 'statement', 'statement'], [9000, 64, 500, 1, 64, 'extension', 'statement', 'statement'], [9000, 69, 500, 1, 64, 'extension', 'statement', 'statement'], [9000, 72, 500, 1, 64, 'extension', 'statement', 'statement'], [9000, 55, 500, 1, 64, 'statement', 'extension', 'statement'], [10000, 52, 500, 1, 64, 'preparation', 'extension', 'statement'], [10000, 67, 500, 1, 64, 'preparation', 'extension', 'statement'], [10000, 72, 500, 1, 64, 'preparation', 'extension', 'statement'], [10000, 76, 500, 1, 64, 'preparation', 'extension', 'statement'], [10500, 50, 500, 1, 64, 'preparation', 'extension', 'statement'], [10500, 67, 500, 1, 64, 'preparation', 'extension', 'statement'], [10500, 72, 500, 1, 64, 'preparation', 'extension', 'statement'], [10500, 76, 500, 1, 64, 'preparation', 'extension', 'statement'], [11000, 48, 1000, 1, 64, 'extension', 'extension', 'statement'], [11000, 67, 1000, 1, 64, 'extension', 'extension', 'statement'], [11000 ...
# ------------------
# file № 11 ; meter =  3 ; result =  [[0, 60, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [0, 64, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [0, 72, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [0, 79, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [1000, 53, 500, 1, 64, 'extension', 'preparation', 'statement'], [1000, 65, 500, 1, 64, 'extension', 'preparation', 'statement'], [1000, 72, 500, 1, 64, 'extension', 'preparation', 'statement'], [1000, 81, 500, 1, 64, 'extension', 'preparation', 'statement'], [1500, 53, 500, 1, 64, 'extension', 'preparation', 'statement'], [1500, 64, 500, 1, 64, 'extension', 'preparation', 'statement'], [1500, 72, 500, 1, 64, 'extension', 'preparation', 'statement'], [1500, 81, 500, 1, 64, 'extension', 'preparation', 'statement'], [2000, 55, 500, 1, 64, 'preparation', 'preparation', 'statement'], [2000, 62, 500, 1, 64, 'preparation', 'preparation', 'statement'], [2000, 71, 500, 1, 64, 'preparation', 'preparation', 'statement'], [2000, 79, 500, 1, 64, 'preparation', 'preparation', 'statement'], [2500, 55, 500, 1, 64, 'preparation', 'preparation', 'statement'], [2500, 62, 500, 1, 64, 'preparation', 'preparation', 'statement'], [2500, 71, 500, 1, 64, 'preparation', 'preparation', 'statement'], [2500, 77, 500, 1, 64, 'preparation', 'preparation', 'statement'], [3000, 57, 500, 1, 64, 'extension', 'preparation', 'statement'], [3000, 69, 500, 1, 64, 'extension', 'preparation', 'statement'], [3000, 72, 500, 1, 64, 'extension', 'preparation', 'statement'], [3000, 76, 500, 1, 64, 'extension', 'preparation', 'statement'], [3500, 57, 500, 1, 64, 'extension', 'preparation', 'statement'], [3500, 69, 500, 1, 64, 'extension', 'preparation', 'statement'], [3500, 72, 500, 1, 64, 'extension', 'preparation', 'statement'], [3500, 77, 500, 1, 64, 'extension', 'preparation', 'statement'], [4000, 59, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [4000, 62, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [4000, 71, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [4000, 79, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [4500, 60, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [4500, 64, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [4500, 71, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [4500, 79, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [5000, 62, 500, 1, 64, 'statement', 'preparation', 'statement'], [5000, 65, 500, 1, 64, 'statement', 'preparation', 'statement'], [5000, 69, 500, 1, 64, 'statement', 'preparation', 'statement'], [5000, 77, 500, 1, 64, 'statement', 'preparation', 'statement'], [5500, 62, 500, 1, 64, 'statement', 'preparation', 'statement'], [5500, 69, 500, 1, 64, 'statement', 'preparation', 'statement'], [5500, 72, 500, 1, 64, 'statement', 'preparation', 'statement'], [5500, 76, 500, 1, 64, 'statement', 'preparation', 'statement'], [6000, 55, 500, 1, 64, 'statement', 'preparation', 'statement'], [6000, 67, 500, 1, 64, 'statement', 'preparation', 'statement'], [6000, 72, 500, 1, 64, 'statement', 'preparation', 'statement'], [6000, 77, 500, 1, 64, 'statement', 'preparation', 'statement'], [6500, 55, 500, 1, 64, 'statement', 'preparation', 'statement'], [6500, 67, 500, 1, 64, 'statement', 'preparation', 'statement'], [6500, 71, 500, 1, 64, 'statement', 'preparation', 'statement'], [6500, 77, 500, 1, 64, 'statement', 'preparation', 'statement'], [7000, 60, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [7000, 67, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [7000, 72, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [7000, 76, 1000, 1, 64, 'preparation', 'preparation', 'statement'], [8000, 59, 1000, 1, 64, 'extension', 'preparation', 'statement'], [8000, 67, 1000, 1, 64, 'extension', 'preparation', 'statement'], [8000, 74, 1000, 1, 64, 'extension', 'preparation', 'statement'], [8000, 74, 1000, 1, 64, 'extension', 'preparation', 'statement'], [9000, 60, 500, 1, 64, ' ...
# ------------------
# ...
# ------------------
# file № 26 ; meter =  3 ; result =  [[0, 59, 500, 1, 100, 'statement', 'statement', 'statement'], [0, 62, 500, 1, 100, 'statement', 'statement', 'statement'], [0, 66, 500, 1, 100, 'statement', 'statement', 'statement'], [0, 71, 500, 1, 100, 'statement', 'statement', 'statement'], [500, 57, 500, 1, 100, 'statement', 'statement', 'statement'], [500, 62, 500, 1, 100, 'statement', 'statement', 'statement'], [500, 66, 500, 1, 100, 'statement', 'statement', 'statement'], [500, 71, 500, 1, 100, 'statement', 'statement', 'statement'], [1000, 55, 500, 1, 100, 'antecedent', 'statement', 'statement'], [1000, 61, 500, 1, 100, 'antecedent', 'statement', 'statement'], [1000, 64, 500, 1, 100, 'antecedent', 'statement', 'statement'], [1000, 71, 500, 1, 100, 'antecedent', 'statement', 'statement'], [1500, 55, 500, 1, 100, 'antecedent', 'statement', 'statement'], [1500, 59, 500, 1, 100, 'antecedent', 'statement', 'statement'], [1500, 64, 500, 1, 100, 'antecedent', 'statement', 'statement'], [1500, 71, 500, 1, 100, 'antecedent', 'statement', 'statement'], [2000, 54, 500, 1, 100, 'statement', 'statement', 'statement'], [2000, 61, 500, 1, 100, 'statement', 'statement', 'statement'], [2000, 66, 500, 1, 100, 'statement', 'statement', 'statement'], [2000, 69, 500, 1, 100, 'statement', 'statement', 'statement'], [2500, 52, 500, 1, 100, 'statement', 'statement', 'statement'], [2500, 61, 500, 1, 100, 'statement', 'statement', 'statement'], [2500, 66, 500, 1, 100, 'statement', 'statement', 'statement'], [2500, 69, 500, 1, 100, 'statement', 'statement', 'statement'], [3000, 50, 500, 1, 100, 'preparation', 'statement', 'statement'], [3000, 59, 500, 1, 100, 'preparation', 'statement', 'statement'], [3000, 66, 500, 1, 100, 'preparation', 'statement', 'statement'], [3000, 74, 500, 1, 100, 'preparation', 'statement', 'statement'], [3500, 47, 250, 1, 100, 'preparation', 'statement', 'statement'], [3500, 59, 250, 1, 100, 'preparation', 'statement', 'statement'], [3500, 67, 250, 1, 100, 'preparation', 'statement', 'statement'], [3500, 74, 250, 1, 100, 'preparation', 'statement', 'statement'], [3750, 47, 250, 1, 100, 'preparation', 'statement', 'statement'], [3750, 59, 250, 1, 100, 'preparation', 'statement', 'statement'], [3750, 69, 250, 1, 100, 'preparation', 'statement', 'statement'], [3750, 74, 250, 1, 100, 'preparation', 'statement', 'statement'], [4000, 52, 500, 1, 100, 'extension', 'statement', 'statement'], [4000, 59, 500, 1, 100, 'extension', 'statement', 'statement'], [4000, 67, 500, 1, 100, 'extension', 'statement', 'statement'], [4000, 73, 500, 1, 100, 'extension', 'statement', 'statement'], [4500, 50, 500, 1, 100, 'extension', 'statement', 'statement'], [4500, 59, 500, 1, 100, 'extension', 'statement', 'statement'], [4500, 66, 500, 1, 100, 'extension', 'statement', 'statement'], [4500, 71, 500, 1, 100, 'extension', 'statement', 'statement'], [5000, 52, 500, 1, 100, 'extension', 'statement', 'statement'], [5000, 59, 500, 1, 100, 'extension', 'statement', 'statement'], [5000, 64, 500, 1, 100, 'extension', 'statement', 'statement'], [5000, 73, 500, 1, 100, 'extension', 'statement', 'statement'], [5500, 54, 500, 1, 100, 'extension', 'statement', 'statement'], [5500, 58, 500, 1, 100, 'extension', 'statement', 'statement'], [5500, 64, 500, 1, 100, 'extension', 'statement', 'statement'], [5500, 73, 500, 1, 100, 'extension', 'statement', 'statement'], [6000, 47, 2000, 1, 100, 'extension', 'statement', 'statement'], [6000, 54, 2000, 1, 100, 'extension', 'statement', 'statement'], [6000, 62, 2000, 1, 100, 'extension', 'statement', 'statement'], [6000, 71, 2000, 1, 100, 'extension', 'statement', 'statement'], [8000, 47, 500, 1, 100, 'preparation', 'statement', 'statement'], [8000, 62, 500, 1, 100, 'preparation', 'statement', 'statement'], [8000, 66, 500, 1, 100, 'preparation', 'statement', 'statement'], [8000, 71, 500, 1, 100, 'preparation', 'statement', 'statement'], [8500, 47, 500, 1, 100, 'preparation', 'statement', 'statement'], [8500, 61, 500, 1, 100, 'prepa ...
# ------------------
# file № 27 ; meter =  3 ; result =  [[0, 55, 1000, 1, 100, 'statement', 'preparation', 'statement'], [0, 59, 1000, 1, 100, 'statement', 'preparation', 'statement'], [0, 62, 1000, 1, 100, 'statement', 'preparation', 'statement'], [0, 67, 1000, 1, 100, 'statement', 'preparation', 'statement'], [1000, 54, 1000, 1, 100, 'antecedent', 'preparation', 'statement'], [1000, 57, 1000, 1, 100, 'antecedent', 'preparation', 'statement'], [1000, 62, 1000, 1, 100, 'antecedent', 'preparation', 'statement'], [1000, 69, 1000, 1, 100, 'antecedent', 'preparation', 'statement'], [2000, 55, 1000, 1, 100, 'statement', 'preparation', 'statement'], [2000, 55, 1000, 1, 100, 'statement', 'preparation', 'statement'], [2000, 62, 1000, 1, 100, 'statement', 'preparation', 'statement'], [2000, 71, 1000, 1, 100, 'statement', 'preparation', 'statement'], [3000, 50, 500, 1, 100, 'statement', 'preparation', 'statement'], [3000, 55, 500, 1, 100, 'statement', 'preparation', 'statement'], [3000, 62, 500, 1, 100, 'statement', 'preparation', 'statement'], [3000, 69, 500, 1, 100, 'statement', 'preparation', 'statement'], [3500, 50, 500, 1, 100, 'statement', 'preparation', 'statement'], [3500, 54, 500, 1, 100, 'statement', 'preparation', 'statement'], [3500, 62, 500, 1, 100, 'statement', 'preparation', 'statement'], [3500, 69, 500, 1, 100, 'statement', 'preparation', 'statement'], [4000, 52, 500, 1, 100, 'extension', 'preparation', 'statement'], [4000, 55, 500, 1, 100, 'extension', 'preparation', 'statement'], [4000, 62, 500, 1, 100, 'extension', 'preparation', 'statement'], [4000, 67, 500, 1, 100, 'extension', 'preparation', 'statement'], [4500, 52, 500, 1, 100, 'extension', 'preparation', 'statement'], [4500, 55, 500, 1, 100, 'extension', 'preparation', 'statement'], [4500, 61, 500, 1, 100, 'extension', 'preparation', 'statement'], [4500, 67, 500, 1, 100, 'extension', 'preparation', 'statement'], [5000, 54, 500, 1, 100, 'extension', 'preparation', 'statement'], [5000, 57, 500, 1, 100, 'extension', 'preparation', 'statement'], [5000, 62, 500, 1, 100, 'extension', 'preparation', 'statement'], [5000, 66, 500, 1, 100, 'extension', 'preparation', 'statement'], [5500, 55, 500, 1, 100, 'extension', 'preparation', 'statement'], [5500, 57, 500, 1, 100, 'extension', 'preparation', 'statement'], [5500, 62, 500, 1, 100, 'extension', 'preparation', 'statement'], [5500, 66, 500, 1, 100, 'extension', 'preparation', 'statement'], [6000, 57, 500, 1, 100, 'antecedent', 'preparation', 'statement'], [6000, 57, 500, 1, 100, 'antecedent', 'preparation', 'statement'], [6000, 61, 500, 1, 100, 'antecedent', 'preparation', 'statement'], [6000, 64, 500, 1, 100, 'antecedent', 'preparation', 'statement'], [6500, 55, 500, 1, 100, 'antecedent', 'preparation', 'statement'], [6500, 57, 500, 1, 100, 'antecedent', 'preparation', 'statement'], [6500, 61, 500, 1, 100, 'antecedent', 'preparation', 'statement'], [6500, 64, 500, 1, 100, 'antecedent', 'preparation', 'statement'], [7000, 50, 1000, 1, 100, 'consequent', 'preparation', 'statement'], [7000, 54, 1000, 1, 100, 'consequent', 'preparation', 'statement'], [7000, 57, 1000, 1, 100, 'consequent', 'preparation', 'statement'], [7000, 62, 1000, 1, 100, 'consequent', 'preparation', 'statement'], [8000, 52, 1000, 1, 100, 'preparation', 'preparation', 'statement'], [8000, 59, 1000, 1, 100, 'preparation', 'preparation', 'statement'], [8000, 64, 1000, 1, 100, 'preparation', 'preparation', 'statement'], [8000, 67, 1000, 1, 100, 'preparation', 'preparation', 'statement'], [9000, 54, 1000, 1, 100, 'extension', 'preparation', 'statement'], [9000, 57, 1000, 1, 100, 'extension', 'preparation', 'statement'], [9000, 62, 1000, 1, 100, 'extension', 'preparation', 'statement'], [9000, 69, 1000, 1, 100, 'extension', 'preparation', 'statement'], [10000, 55, 500, 1, 100, 'statement', 'extension', 'statement'], [10000, 55, 500, 1, 100, 'statement', 'extension', 'statement'], [10000, 62, 500, 1, 100, 'statement', 'extension', 'statement'], [10000, 71, 500, 1, 100, 'statement', ...
# ------------------
# file № 28 ; meter =  3 ; result =  [[0, 52, 1000, 1, 100, 'statement', 'antecedent', 'statement'], [0, 55, 1000, 1, 100, 'statement', 'antecedent', 'statement'], [0, 59, 1000, 1, 100, 'statement', 'antecedent', 'statement'], [0, 64, 1000, 1, 100, 'statement', 'antecedent', 'statement'], [1000, 52, 500, 1, 100, 'statement', 'antecedent', 'statement'], [1000, 54, 500, 1, 100, 'statement', 'antecedent', 'statement'], [1000, 59, 500, 1, 100, 'statement', 'antecedent', 'statement'], [1000, 71, 500, 1, 100, 'statement', 'antecedent', 'statement'], [1500, 50, 500, 1, 100, 'statement', 'antecedent', 'statement'], [1500, 54, 500, 1, 100, 'statement', 'antecedent', 'statement'], [1500, 59, 500, 1, 100, 'statement', 'antecedent', 'statement'], [1500, 71, 500, 1, 100, 'statement', 'antecedent', 'statement'], [2000, 48, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [2000, 55, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [2000, 64, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [2000, 71, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [2500, 48, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [2500, 55, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [2500, 63, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [2500, 71, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [3000, 48, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [3000, 54, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [3000, 64, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [3000, 69, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [3500, 48, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [3500, 52, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [3500, 64, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [3500, 69, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [4000, 47, 500, 1, 100, 'extension', 'antecedent', 'statement'], [4000, 54, 500, 1, 100, 'extension', 'antecedent', 'statement'], [4000, 63, 500, 1, 100, 'extension', 'antecedent', 'statement'], [4000, 71, 500, 1, 100, 'extension', 'antecedent', 'statement'], [4500, 54, 500, 1, 100, 'extension', 'antecedent', 'statement'], [4500, 57, 500, 1, 100, 'extension', 'antecedent', 'statement'], [4500, 63, 500, 1, 100, 'extension', 'antecedent', 'statement'], [4500, 71, 500, 1, 100, 'extension', 'antecedent', 'statement'], [5000, 55, 500, 1, 100, 'statement', 'antecedent', 'statement'], [5000, 59, 500, 1, 100, 'statement', 'antecedent', 'statement'], [5000, 64, 500, 1, 100, 'statement', 'antecedent', 'statement'], [5000, 64, 500, 1, 100, 'statement', 'antecedent', 'statement'], [5500, 54, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [5500, 57, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [5500, 63, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [5500, 66, 500, 1, 100, 'preparation', 'antecedent', 'statement'], [6000, 52, 500, 1, 100, 'extension', 'antecedent', 'statement'], [6000, 59, 500, 1, 100, 'extension', 'antecedent', 'statement'], [6000, 64, 500, 1, 100, 'extension', 'antecedent', 'statement'], [6000, 67, 500, 1, 100, 'extension', 'antecedent', 'statement'], [6500, 50, 500, 1, 100, 'extension', 'antecedent', 'statement'], [6500, 59, 500, 1, 100, 'extension', 'antecedent', 'statement'], [6500, 64, 500, 1, 100, 'extension', 'antecedent', 'statement'], [6500, 67, 500, 1, 100, 'extension', 'antecedent', 'statement'], [7000, 48, 500, 1, 100, 'statement', 'antecedent', 'statement'], [7000, 64, 500, 1, 100, 'statement', 'antecedent', 'statement'], [7000, 64, 500, 1, 100, 'statement', 'antecedent', 'statement'], [7000, 67, 500, 1, 100, 'statement', 'antecedent', 'statement'], [7500, 47, 500, 1, 100, 'statement', 'antecedent', 'statement'], [7500, 63, 500, 1, 100, 'statement', 'antecedent', 'statement'], [7500, 64, 500, 1, 100, 'statement', 'antecedent', 'statement'], [7500, 67, 500, 1, 100, 'statement', 'antecedent', 'statement'], [8000, 46, 1000, 1, 100, 'antece ...
# ------------------

# %% [markdown]
# События последовательно записываются друг за другом

# %%
one_big_input = []
big_offset = 0

for speac_analysis in speac_analyzes:
    for event in speac_analysis:
            new_event = copy.deepcopy(event)
            new_event[0] += big_offset
            one_big_input.append(new_event)
    
    big_offset += speac_analysis[-1][0] + speac_analysis[-1][2]

print(one_big_input)
# Out:
# [[0, 48, 1000, 1, 64, 'statement', 'preparation', 'statement'], [0, 60, 1000, 1, 64, 'statement', 'preparation', 'statement'], [0, 64, 1000, 1, 64, 'statement', 'preparation', 'statement'], [0, 67, 1000, 1, 64, 'statement', 'preparation', 'statement'], [1000, 47, 500, 1, 64, 'extension', 'preparation', 'statement'], [1000, 62, 500, 1, 64, 'extension', 'preparation', 'statement'], [1000, 62, 500, 1, 64, 'extension', 'preparation', 'statement'], [1000, 67, 500, 1, 64, 'extension', 'preparation', 'statement'], [1500, 47, 500, 1, 64, 'extension', 'preparation', 'statement'], [1500, 62, 500, 1, 64, 'extension', 'preparation', 'statement'], [1500, 64, 500, 1, 64, 'extension', 'preparation', 'statement'], [1500, 67, 500, 1, 64, 'extension', 'preparation', 'statement'], [2000, 43, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2000, 60, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2000, 65, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2000, 67, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2500, 43, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2500, 59, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2500, 65, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [2500, 67, 500, 1, 64, 'antecedent', 'preparation', 'statement'], [3000, 48, 1000, 1, 64, 'statement', 'preparation', 'statement'], [3000, 60, 1000, 1, 64, 'statement', 'preparation', 'statement'], [3000, 64, 1000, 1, 64, 'statement', 'preparation', 'statement'], [3000, 67, 1000, 1, 64, 'statement', 'preparation', 'statement'], [4000, 50, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4000, 53, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4000, 62, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4000, 70, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4500, 52, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4500, 55, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4500, 62, 500, 1, 64, 'preparation', 'preparation', 'statement'], [4500, 70, 500, 1, 64, 'preparation', 'preparation', 'statement'], [5000, 53, 250, 1, 64, 'extension', 'preparation', 'statement'], [5000, 57, 250, 1, 64, 'extension', 'preparation', 'statement'], [5000, 60, 250, 1, 64, 'extension', 'preparation', 'statement'], [5000, 69, 250, 1, 64, 'extension', 'preparation', 'statement'], [5250, 53, 250, 1, 64, 'extension', 'preparation', 'statement'], [5250, 58, 250, 1, 64, 'extension', 'preparation', 'statement'], [5250, 60, 250, 1, 64, 'extension', 'preparation', 'statement'], [5250, 69, 250, 1, 64, 'extension', 'preparation', 'statement'], [5500, 53, 500, 1, 64, 'extension', 'preparation', 'statement'], [5500, 60, 500, 1, 64, 'extension', 'preparation', 'statement'], [5500, 65, 500, 1, 64, 'extension', 'preparation', 'statement'], [5500, 69, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 48, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 60, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 65, 500, 1, 64, 'extension', 'preparation', 'statement'], [6000, 67, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 48, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 58, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 64, 500, 1, 64, 'extension', 'preparation', 'statement'], [6500, 67, 500, 1, 64, 'extension', 'preparation', 'statement'], [7000, 41, 1000, 1, 64, 'statement', 'preparation', 'statement'], [7000, 57, 1000, 1, 64, 'statement', 'preparation', 'statement'], [7000, 60, 1000, 1, 64, 'statement', 'preparation', 'statement'], [7000, 65, 1000, 1, 64, 'statement', 'preparation', 'statement'], [8000, 47, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [8000, 55, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [8000, 62, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [8000, 67, 1000, 1, 64, 'antecedent', 'preparation', 'statement'], [9000, 48, 500, 1, 64, 'consequent', 'preparation', 'statement'], [ ...

# %% [markdown]
# Кодирование каждого бита (одновременно играющихся событий) в формате: "midi.midi.midi", предложенном в статье https://towardsdatascience.com/how-to-generate-music-using-a-lstm-neural-network-in-keras-68786834d4c5

# %%
notes_article = []
current_chord = None

last_event_offset = None

for event in one_big_input:
    event_offset = event[0]
    
    if last_event_offset is None:
        current_chord = str(event[1])
    
    elif event_offset > last_event_offset:
        notes_article.append(current_chord)
        current_chord = str(event[1])

    else:
        current_chord = current_chord + "." + str(event[1])

    last_event_offset = event_offset
    
print(notes_article)
# Out:
# ['48.60.64.67', '47.62.62.67', '47.62.64.67', '43.60.65.67', '43.59.65.67', '48.60.64.67', '50.53.62.70', '52.55.62.70', '53.57.60.69', '53.58.60.69', '53.60.65.69', '48.60.65.67', '48.58.64.67', '41.57.60.65', '47.55.62.67', '48.55.60.64', '50.55.60.64', '52.55.60.60', '52.53.59.62', '45.52.60.64', '50.50.57.66', '48.50.57.66', '47.50.62.67', '45.55.60.67', '43.55.59.67', '50.55.60.69', '50.54.60.69', '43.50.59.67', '48.60.64.67', '47.62.62.67', '47.62.64.67', '43.60.65.67', '43.59.65.67', '48.60.64.67', '50.53.62.70', '52.55.62.70', '53.57.60.69', '53.58.60.69', '53.60.65.69', '48.60.65.67', '48.58.64.67', '41.57.60.65', '47.55.62.67', '48.55.60.64', '50.55.60.64', '52.55.60.60', '52.53.59.62', '45.52.60.64', '50.50.57.66', '48.50.57.66', '47.50.62.67', '45.55.60.67', '43.55.59.67', '50.55.60.69', '50.54.60.69', '43.50.59.67', '48.52.60.67', '48.52.62.67', '45.57.64.72', '45.57.66.72', '47.50.67.71', '48.50.67.71', '50.62.66.69', '55.62.67.71', '52.55.67.72', '48.55.67.71', '50.54.62.69', '43.59.62.67', '48.60.64.67', '52.55.60.72', '52.55.62.72', '48.60.64.67', '53.60.65.69', '55.60.65.69', '57.57.60.64', '57.57.62.65', '49.58.64.67', '50.57.62.65', '45.57.61.64', '48.55.60.64', '43.55.59.62', '45.57.60.65', '47.57.60.65', '48.55.60.64', '43.55.59.62', '43.55.55.62', '42.50.57.57', '43.50.55.59', '36.52.55.60', '50.56.64.71', '48.57.64.64', '47.62.68.71', '45.64.69.72', '47.62.67.71', '47.62.66.69', '48.64.64.67', '47.62.64.67', '45.60.66.69', '52.59.68.71', '52.64.68.71', '57.64.69.72', '55.65.71.74', '53.65.71.74', '52.67.72.72', '52.67.71.72', '53.60.65.69', '48.60.64.67', '48.59.64.67', '50.57.62.65', '50.57.60.65', '52.56.59.64', '50.56.64.71', '48.57.64.64', '47.62.68.71', '45.64.69.72', '47.62.67.71', '47.62.66.69', '48.64.64.67', '47.62.64.67', '45.60.66.69', '52.59.68.71', '52.64.68.71', '57.64.69.72', '55.65.71.74', '53.65.71.74', '52.67.72.72', '52.67.71.72', '53.60.65.69', '48.60.64.67', '48.59.64.67', '50.57.62.65', '50.57.60.65', '52.56.59.64', '48.57.64.69', '47.59.62.67', '45.60.64.72', '45.60.66.72', '43.62.67.71', '55.62.67.71', '53.62.69.69', '52.64.69.69', '50.65.71.74', '50.65.69.72', '52.59.68.71', '45.60.64.69', '57.64.69.72', '52.64.67.71', '50.64.67.72', '48.64.67.72', '47.62.67.74', '47.62.65.74', '48.60.64.67', '50.54.62.71', '50.55.62.71', '38.55.60.69', '38.54.60.69', '43.55.59.67', '43.55.59', '48.55.64.67', '45.57.64.72', '52.56.64.71', '52.56.62.71', '53.57.60.69', '48.55.60.64', '46.55.62.67', '45.57.62.65', '44.59.62.64', '45.57.60.64', '40.56.59.64', '48.64.67.72', '60.64.67.72', '57.65.69.72', '57.64.69.72', '59.62.67.79', '60.60.67.76', '55.59.67.76', '55.59.67.74', '57.60.64.72', '53.65.69.72', '53.64.67.72', '52.65.69.72', '50.65.71.74', '48.67.72.76', '55.67.71.74', '48.67.72.76', '47.62.67.79', '48.64.69.79', '50.65.71.77', '52.67.72.76', '53.69.72.74', '55.67.71.74', '55.65.71.74', '48.64.67.72', '48.64.67.72', '60.64.67.72', '57.65.69.72', '57.64.69.72', '59.62.67.79', '60.60.67.76', '55.59.67.76', '55.59.67.74', '57.60.64.72', '53.65.69.72', '53.64.67.72', '52.65.69.72', '50.65.71.74', '48.67.72.76', '55.67.71.74', '48.67.72.76', '47.62.67.79', '48.64.69.79', '50.65.71.77', '52.67.72.76', '53.69.72.74', '55.67.71.74', '55.65.71.74', '48.64.67.72', '48.67.72.76', '48.67.72.76', '48.67.71.76', '50.65.69.77', '50.65.71.77', '52.64.72.79', '52.62.72.79', '52.64.72.79', '52.65.74.79', '52.67.72.79', '50.67.71.77', '48.67.72.76', '55.67.71.74', '57.64.69.72', '57.60.69.76', '55.64.71.76', '55.64.72.76', '53.69.74.77', '52.67.74.79', '52.67.79', '67.79.72', '53.72', '55.67.72.77', '55.67.71.77', '48.67.72.76', '50.67.72.76', '52.67.72.76', '48.67.70.76', '53.65.69.72', '48.67.72.76', '47.67.74.79', '47.65.74.79', '48.64.74.79', '48.64.72.79', '50.65.71.77', '52.67.72.76', '48.67.72.76', '55.67.71.74', '55.65.71.74', '57.64.71.72', '55.64.69.72', '53.65.69.72', '52.65.71.74', '50.67.72.76', '48.67.72.76', '55.67.71.74', '60.67.72.76', '60.67.74.79', '59.67.74.79', '57.69.72.77', '57.69.71 ...

# %% [markdown]
# Если после установки что-то в коде не работает, то есть вероятность, что надо сбросить настройки в среде выполнения или изменить её на TPU соответственно)))

# %%
import tensorflow as tf
import os

resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])

tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# WARNING:tensorflow:TPU system grpc://10.88.227.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.88.227.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.88.227.18:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.88.227.18:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU')]

# %% [markdown]
# TPU имеет 8 логических устройств TPU (0–7), которые могут выполнять параллельную обработку. Следовательно, мы определяем стратегию распределения для распределенного обучения по этим 8 устройствам:

# %%
strategy = tf.distribute.TPUStrategy(resolver)
# Out:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %% [markdown]
# Подготовка данных для обучения модели из статьи

# %%
#Минимальное необходимое число нот в обучающих произведениях
sequence_length = 8

#Сортировка всех повторяющихся нот в множество неповторяющихся (Set)
pitchnames_article = sorted(set(item for item in notes_article))

#Отображаем каждый аккорд или ноту на некоторое число (по сути Map)
note_to_int_article = dict((note, number) for number, note in enumerate(pitchnames_article))

network_input_article = []
network_output_article = []

for i in range(0, len(notes_article) - sequence_length, 1):
    #записываем сначала первые 100 нот, затем 1-101, 2-102 и т.д
    sequence_in_article = notes_article[i:i + sequence_length]

    #узнаём какой должна быть следующая нота
    sequence_out_article = notes_article[i + sequence_length]

    #ноты преобразуем в номера из созданного Map
    network_input_article.append([note_to_int_article[char] for char in sequence_in_article])

    #преобразуем следующую ноту в номер из созданного Map
    network_output_article.append(note_to_int_article[sequence_out_article])

n_patterns_article = len(network_input_article)

#Преобразование входной выборки в формат, удобный для работы с LSTM
network_input_article = numpy.reshape(network_input_article, (n_patterns_article, sequence_length, 1))

n_vocab_article = len(set(notes_article))
# n_vocab = max(set(network_output)) + 1

#Нормализация
network_input_article = network_input_article / float(n_vocab_article)

network_output_article = np_utils.to_categorical(network_output_article)

print(network_input_article[0])
# Out:
# [[0.26683292]
#  [0.21030756]
#  [0.21113882]
#  [0.08312552]
#  [0.07813799]
#  [0.26683292]
#  [0.32751455]
#  [0.46716542]]

# %%
def create_model(network_input, n_vocab):
  model = Sequential()
  model.add(LSTM(
        256,
        input_shape=(network_input.shape[1], 
                     network_input.shape[2]),
        return_sequences=True
    ))
  model.add(Dropout(0.3))
  model.add(LSTM(512, return_sequences=True))
  model.add(Dropout(0.3))
  model.add(LSTM(256))
  model.add(Dense(256))
  model.add(Dropout(0.3))
  model.add(Dense(n_vocab))
  model.add(Activation('softmax'))

  model.summary()

  return model

# %% [markdown]
# Компиляция модели

# %%
with strategy.scope():
    model_article = create_model(network_input_article, n_vocab_article)
    model_article.compile(loss='categorical_crossentropy', optimizer='rmsprop')
    print("model_article is compilled")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 8, 256)            264192
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 256)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8, 512)            1574912
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 512)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 256)               787456
# _________________________________________________________________
# dense (Dense)                (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1203)              309171
# _________________________________________________________________
# activation (Activation)      (None, 1203)              0
# =================================================================
# Total params: 3,001,523
# Trainable params: 3,001,523
# Non-trainable params: 0
# _________________________________________________________________
# model_article is compilled

# %% [markdown]
# Обучение модели

# %%
model_article.fit(network_input_article, network_output_article, epochs=200, batch_size=64)
# Out:
# Epoch 1/200
# 43/43 [==============================] - 29s 79ms/step - loss: 7.0183
# Epoch 2/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.7539
# Epoch 3/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.7263
# Epoch 4/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.6173
# Epoch 5/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.6102
# Epoch 6/200
# 43/43 [==============================] - 1s 17ms/step - loss: 6.5597
# Epoch 7/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.4912
# Epoch 8/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.5048
# Epoch 9/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.4285
# Epoch 10/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.4167
# Epoch 11/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.4099
# Epoch 12/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.3338
# Epoch 13/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.2777
# Epoch 14/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.2727
# Epoch 15/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.2103
# Epoch 16/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.2051
# Epoch 17/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.0748
# Epoch 18/200
# 43/43 [==============================] - 1s 16ms/step - loss: 6.1038
# Epoch 19/200
# 43/43 [==============================] - 1s 15ms/step - loss: 5.9767
# Epoch 20/200
# 43/43 [==============================] - 1s 16ms/step - loss: 5.9056
# Epoch 21/200
# 43/43 [==============================] - 1s 16ms/step - loss: 5.8705
# Epoch 22/200
# 43/43 [==============================] - 1s 15ms/step - loss: 5.7609
# Epoch 23/200
# 43/43 [==============================] - 1s 17ms/step - loss: 5.7610
# Epoch 24/200
# 43/43 [==============================] - 1s 15ms/step - loss: 5.7178
# Epoch 25/200
# 43/43 [==============================] - 1s 16ms/step - loss: 5.6393
# Epoch 26/200
# 43/43 [==============================] - 1s 16ms/step - loss: 5.5968
# Epoch 27/200
# 43/43 [==============================] - 1s 16ms/step - loss: 5.5145
# Epoch 28/200
# 43/43 [==============================] - 1s 15ms/step - loss: 5.4479
# Epoch 29/200
# 43/43 [==============================] - 1s 16ms/step - loss: 5.4380
# Epoch 30/200
# 43/43 [==============================] - 1s 15ms/step - loss: 5.3738
# Epoch 31/200
# 43/43 [==============================] - 1s 16ms/step - loss: 5.3044
# Epoch 32/200
# 43/43 [==============================] - 1s 16ms/step - loss: 5.2275
# Epoch 33/200
# 43/43 [==============================] - 1s 16ms/step - loss: 5.1171
# Epoch 34/200
# 43/43 [==============================] - 1s 16ms/step - loss: 5.0162
# Epoch 35/200
# 43/43 [==============================] - 1s 16ms/step - loss: 5.0094
# Epoch 36/200
# 43/43 [==============================] - 1s 16ms/step - loss: 4.9409
# Epoch 37/200
# 43/43 [==============================] - 1s 16ms/step - loss: 4.8526
# Epoch 38/200
# 43/43 [==============================] - 1s 17ms/step - loss: 4.7515
# Epoch 39/200
# 43/43 [==============================] - 1s 16ms/step - loss: 4.7258
# Epoch 40/200
# 43/43 [==============================] - 1s 16ms/step - loss: 4.7069
# Epoch 41/200
# 43/43 [==============================] - 1s 15ms/step - loss: 4.5656
# Epoch 42/200
# 43/43 [==============================] - 1s 16ms/step - loss: 4.4953
# Epoch 43/200
# 43/43 [==============================] - 1s 16ms/step - loss: 4.4928
# Epoch 44/200
# 43/43 [==============================] - 1s 16ms/step - loss: 4.3907
# Epoch 45/200
# 43/43 [==============================] - 1s 16ms/step - loss: 4.4197
# Epoch 46/200
# 43/43 [==============================] - 1s 16ms/step - loss: 4.3111
# Epoch 47/200
# 43/43 [==============================] - 1s 16ms/step - loss: 4.1568
# Epoch 48/200
# 43/43 [==============================] - 1s 16ms/step - loss: 4.1851
# Epoch 49/200
# 43/43 [==============================] - 1s 16ms/step - loss: 4.0749
# Epoch 50/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.9428
# Epoch 51/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.9752
# Epoch 52/200
# 43/43 [==============================] - 1s 17ms/step - loss: 3.8158
# Epoch 53/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.7520
# Epoch 54/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.7749
# Epoch 55/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.6543
# Epoch 56/200
# 43/43 [==============================] - 1s 15ms/step - loss: 3.6793
# Epoch 57/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.6537
# Epoch 58/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.3791
# Epoch 59/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.4360
# Epoch 60/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.3860
# Epoch 61/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.2893
# Epoch 62/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.2851
# Epoch 63/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.1665
# Epoch 64/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.1164
# Epoch 65/200
# 43/43 [==============================] - 1s 16ms/step - loss: 3.0058
# Epoch 66/200
# 43/43 [==============================] - 1s 16ms/step - loss: 2.9483
# Epoch 67/200
# 43/43 [==============================] - 1s 16ms/step - loss: 2.9126
# Epoch 68/200
# 43/43 [==============================] - 1s 17ms/step - loss: 2.8822
# Epoch 69/200
# 43/43 [==============================] - 1s 15ms/step - loss: 2.8328
# Epoch 70/200
# 43/43 [==============================] - 1s 16ms/step - loss: 2.7865
# Epoch 71/200
# 43/43 [==============================] - 1s 16ms/step - loss: 2.7249
# Epoch 72/200
# 43/43 [==============================] - 1s 16ms/step - loss: 2.6175
# Epoch 73/200
# 43/43 [==============================] - 1s 17ms/step - loss: 2.5511
# Epoch 74/200
# 43/43 [==============================] - 1s 17ms/step - loss: 2.6155
# Epoch 75/200
# 43/43 [==============================] - 1s 17ms/step - loss: 2.5606
# Epoch 76/200
# 43/43 [==============================] - 1s 17ms/step - loss: 2.4502
# Epoch 77/200
# 43/43 [==============================] - 1s 17ms/step - loss: 2.4165
# Epoch 78/200
# 43/43 [==============================] - 1s 17ms/step - loss: 2.4114
# Epoch 79/200
# 43/43 [==============================] - 1s 17ms/step - loss: 2.3185
# Epoch 80/200
# 43/43 [==============================] - 1s 17ms/step - loss: 2.3001
# Epoch 81/200
# 43/43 [==============================] - 1s 17ms/step - loss: 2.3329
# Epoch 82/200
# 43/43 [==============================] - 1s 17ms/step - loss: 2.2885
# Epoch 83/200
# 43/43 [==============================] - 1s 18ms/step - loss: 2.2111
# Epoch 84/200
# 43/43 [==============================] - 1s 17ms/step - loss: 2.1137
# Epoch 85/200
# 43/43 [==============================] - 1s 17ms/step - loss: 2.1219
# Epoch 86/200
# 43/43 [==============================] - 1s 16ms/step - loss: 2.0019
# Epoch 87/200
# 43/43 [==============================] - 1s 16ms/step - loss: 2.1163
# Epoch 88/200
# 43/43 [==============================] - 1s 16ms/step - loss: 2.0407
# Epoch 89/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.9651
# Epoch 90/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.8949
# Epoch 91/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.9862
# Epoch 92/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.8680
# Epoch 93/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.8347
# Epoch 94/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.8798
# Epoch 95/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.7643
# Epoch 96/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.7126
# Epoch 97/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.6732
# Epoch 98/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.6324
# Epoch 99/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.7167
# Epoch 100/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.6786
# Epoch 101/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.6475
# Epoch 102/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.5679
# Epoch 103/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.5726
# Epoch 104/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.4698
# Epoch 105/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.4496
# Epoch 106/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.4519
# Epoch 107/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.4936
# Epoch 108/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.4087
# Epoch 109/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.3972
# Epoch 110/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.4025
# Epoch 111/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.3054
# Epoch 112/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.3369
# Epoch 113/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.2511
# Epoch 114/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.2488
# Epoch 115/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.2605
# Epoch 116/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.2517
# Epoch 117/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.1365
# Epoch 118/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.1876
# Epoch 119/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.1917
# Epoch 120/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.2466
# Epoch 121/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.1660
# Epoch 122/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.1075
# Epoch 123/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.0893
# Epoch 124/200
# 43/43 [==============================] - 1s 16ms/step - loss: 1.0889
# Epoch 125/200
# 43/43 [==============================] - 1s 18ms/step - loss: 1.1365
# Epoch 126/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.9728
# Epoch 127/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.0346
# Epoch 128/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.9924
# Epoch 129/200
# 43/43 [==============================] - 1s 17ms/step - loss: 1.1006
# Epoch 130/200
# 43/43 [==============================] - 1s 15ms/step - loss: 1.0040
# Epoch 131/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.9290
# Epoch 132/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.9491
# Epoch 133/200
# 43/43 [==============================] - 1s 18ms/step - loss: 0.9545
# Epoch 134/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.9920
# Epoch 135/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.9481
# Epoch 136/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.9084
# Epoch 137/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.9086
# Epoch 138/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.8633
# Epoch 139/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.8874
# Epoch 140/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.8182
# Epoch 141/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.8573
# Epoch 142/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.8128
# Epoch 143/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.8016
# Epoch 144/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.8046
# Epoch 145/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.8123
# Epoch 146/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.7633
# Epoch 147/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.7716
# Epoch 148/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.7301
# Epoch 149/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.7273
# Epoch 150/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.7966
# Epoch 151/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.7801
# Epoch 152/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.7525
# Epoch 153/200
# 43/43 [==============================] - 1s 15ms/step - loss: 0.6945
# Epoch 154/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.6693
# Epoch 155/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.6828
# Epoch 156/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.7562
# Epoch 157/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.6988
# Epoch 158/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.6494
# Epoch 159/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.6948
# Epoch 160/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.6919
# Epoch 161/200
# 43/43 [==============================] - 1s 18ms/step - loss: 0.6483
# Epoch 162/200
# 43/43 [==============================] - 1s 18ms/step - loss: 0.5985
# Epoch 163/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.6156
# Epoch 164/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.6343
# Epoch 165/200
# 43/43 [==============================] - 1s 18ms/step - loss: 0.5900
# Epoch 166/200
# 43/43 [==============================] - 1s 18ms/step - loss: 0.6412
# Epoch 167/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.6399
# Epoch 168/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.5701
# Epoch 169/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.5499
# Epoch 170/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.5941
# Epoch 171/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.5863
# Epoch 172/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.5723
# Epoch 173/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.6011
# Epoch 174/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.5601
# Epoch 175/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.5587
# Epoch 176/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.5789
# Epoch 177/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.5655
# Epoch 178/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.6061
# Epoch 179/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.5800
# Epoch 180/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.5664
# Epoch 181/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.4986
# Epoch 182/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.5289
# Epoch 183/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.5142
# Epoch 184/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.5125
# Epoch 185/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.4830
# Epoch 186/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.5263
# Epoch 187/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.5074
# Epoch 188/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.4908
# Epoch 189/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.4937
# Epoch 190/200
# 43/43 [==============================] - 1s 16ms/step - loss: 0.4773
# Epoch 191/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.4937
# Epoch 192/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.4619
# Epoch 193/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.4845
# Epoch 194/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.4641
# Epoch 195/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.5021
# Epoch 196/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.4821
# Epoch 197/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.4635
# Epoch 198/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.4834
# Epoch 199/200
# 43/43 [==============================] - 1s 17ms/step - loss: 0.4586
# Epoch 200/200
# 43/43 [==============================] - 1s 18ms/step - loss: 0.4486

# %%
model_article.save_weights('/content/drive/My Drive/Examination/Weights/model_article_weights.h5', overwrite=True)

# %% [markdown]
# Генерация следующих битов

# %%
  # start = numpy.random.randint(0, len(network_input_article)-1)
  start = 0
  int_to_note_article = dict((number, note) for number, note in enumerate(pitchnames_article))

  pattern_article = network_input_article[start]

  prediction_output_article = []

  # generate n notes
  for note_index in range(50):
        print("generating ", note_index, " note")
        prediction_input_article = numpy.reshape(pattern_article, (1, len(pattern_article), 1))
        prediction_input_article = prediction_input_article / float(n_vocab_article)

        prediction_article = model_article.predict(prediction_input_article, verbose=0)

        index_article = numpy.argmax(prediction_article)
        result_article = int_to_note_article[index_article]
        prediction_output_article.append(result_article)

        pattern_article = numpy.append(pattern_article, [index_article])
        pattern_article = pattern_article[1:len(pattern_article)]
# Out:
# generating  0  note
# generating  1  note
# generating  2  note
# generating  3  note
# generating  4  note
# generating  5  note
# generating  6  note
# generating  7  note
# generating  8  note
# generating  9  note
# generating  10  note
# generating  11  note
# generating  12  note
# generating  13  note
# generating  14  note
# generating  15  note
# generating  16  note
# generating  17  note
# generating  18  note
# generating  19  note
# generating  20  note
# generating  21  note
# generating  22  note
# generating  23  note
# generating  24  note
# generating  25  note
# generating  26  note
# generating  27  note
# generating  28  note
# generating  29  note
# generating  30  note
# generating  31  note
# generating  32  note
# generating  33  note
# generating  34  note
# generating  35  note
# generating  36  note
# generating  37  note
# generating  38  note
# generating  39  note
# generating  40  note
# generating  41  note
# generating  42  note
# generating  43  note
# generating  44  note
# generating  45  note
# generating  46  note
# generating  47  note
# generating  48  note
# generating  49  note

# %%
import music21
from music21 import *

# %%
def create_new_midi(predicted, file_name):
    offset = 0
    output_notes = []
    # create note and chord objects based on the values generated by the model

    for pattern in predicted:
        # pattern is a chord
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            note_index = 0

            for current_note in notes_in_chord:
                new_note = note.Note(int(current_note))
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)

            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)

        # pattern is a note
        else:
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
                    
            output_notes.append(new_note)

        offset += 1.0

    midi_stream = stream.Stream(output_notes)
    file = midi_stream.write('midi', fp=file_name)

# %%
create_new_midi(prediction_output_article, "article_n=" + str(sequence_length) + ".mid")

# %% [markdown]
# Попытаемся расширить входной вектор так, чтобы на вход нейросети подавался не скаляр, а вектор из 2-х переменных: аккорды и спеак. Будем пытаться повторять эксперимент, который проводил Коуп, когда генерировал музыку. То есть он на основе одного аккорда и желаемого следующего SPEAC-состояния по определённому алгоритму генерировал следующий аккорд. Мы делаем то же самое, но вместо алгоритма Коупа будем использовать нейронную сеть.
# Здесь стоит учесть, что при кодировке всех трёх символов одним разница между foreground состояниями должна быть минимальной, то есть нужно правильно отсортировать данные.

# %%
import tensorflow as tf
import os

resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])

tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# WARNING:tensorflow:TPU system grpc://10.88.227.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.88.227.18:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.88.227.18:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.88.227.18:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)
# Out:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %% [markdown]
# Сортировка SPEAC-состояний по мере напряженности аккорда

# %%
speac_symbols = ["antecedent", "preparation", "extension", "statement", "consequent"]

# %%
speac_map_number = 1
sorted_speac_to_int = {}

for background in speac_symbols:

    for middleground in speac_symbols:

        for foreground in speac_symbols:
            speac_string = str(foreground) + "-" + str(middleground) + "-" + str(background)
            sorted_speac_to_int[speac_string] = speac_map_number
            speac_map_number += 1

# %% [markdown]
# Подготовка данных для обучения

# %%
notes = []
note = []
one_time_notes_set = set()

last_offset = None
one_time_notes = None

for event in one_big_input:
    if last_offset is None:
        one_time_notes = str(event[1])
    
    elif event[0] == last_offset:
        one_time_notes = one_time_notes + "." + str(event[1])
    
    else:
        next_speac = str(event[5]) + "-" + str(event[6]) + "-" + str(event[7])
        note = [one_time_notes, next_speac]
        one_time_notes_set.add(one_time_notes)
        notes.append(note)
        one_time_notes = str(event[1])

    last_offset = event[0]

print(notes)
# Out:
# [['48.60.64.67', 'extension-preparation-statement'], ['47.62.62.67', 'extension-preparation-statement'], ['47.62.64.67', 'antecedent-preparation-statement'], ['43.60.65.67', 'antecedent-preparation-statement'], ['43.59.65.67', 'statement-preparation-statement'], ['48.60.64.67', 'preparation-preparation-statement'], ['50.53.62.70', 'preparation-preparation-statement'], ['52.55.62.70', 'extension-preparation-statement'], ['53.57.60.69', 'extension-preparation-statement'], ['53.58.60.69', 'extension-preparation-statement'], ['53.60.65.69', 'extension-preparation-statement'], ['48.60.65.67', 'extension-preparation-statement'], ['48.58.64.67', 'statement-preparation-statement'], ['41.57.60.65', 'antecedent-preparation-statement'], ['47.55.62.67', 'consequent-preparation-statement'], ['48.55.60.64', 'consequent-preparation-statement'], ['50.55.60.64', 'statement-preparation-statement'], ['52.55.60.60', 'statement-preparation-statement'], ['52.53.59.62', 'extension-preparation-statement'], ['45.52.60.64', 'extension-preparation-statement'], ['50.50.57.66', 'extension-preparation-statement'], ['48.50.57.66', 'preparation-preparation-statement'], ['47.50.62.67', 'preparation-preparation-statement'], ['45.55.60.67', 'preparation-preparation-statement'], ['43.55.59.67', 'preparation-preparation-statement'], ['50.55.60.69', 'preparation-preparation-statement'], ['50.54.60.69', 'extension-preparation-statement'], ['43.50.59.67', 'statement-preparation-statement'], ['48.60.64.67', 'extension-preparation-statement'], ['47.62.62.67', 'extension-preparation-statement'], ['47.62.64.67', 'antecedent-preparation-statement'], ['43.60.65.67', 'antecedent-preparation-statement'], ['43.59.65.67', 'statement-preparation-statement'], ['48.60.64.67', 'preparation-preparation-statement'], ['50.53.62.70', 'preparation-preparation-statement'], ['52.55.62.70', 'extension-preparation-statement'], ['53.57.60.69', 'extension-preparation-statement'], ['53.58.60.69', 'extension-preparation-statement'], ['53.60.65.69', 'extension-preparation-statement'], ['48.60.65.67', 'extension-preparation-statement'], ['48.58.64.67', 'statement-preparation-statement'], ['41.57.60.65', 'antecedent-preparation-statement'], ['47.55.62.67', 'statement-extension-statement'], ['48.55.60.64', 'statement-extension-statement'], ['50.55.60.64', 'extension-extension-statement'], ['52.55.60.60', 'extension-extension-statement'], ['52.53.59.62', 'extension-extension-statement'], ['45.52.60.64', 'extension-extension-statement'], ['50.50.57.66', 'extension-extension-statement'], ['48.50.57.66', 'preparation-extension-statement'], ['47.50.62.67', 'preparation-extension-statement'], ['45.55.60.67', 'preparation-extension-statement'], ['43.55.59.67', 'preparation-extension-statement'], ['50.55.60.69', 'preparation-extension-statement'], ['50.54.60.69', 'extension-extension-statement'], ['43.50.59.67', 'statement-extension-statement'], ['48.52.60.67', 'statement-extension-statement'], ['48.52.62.67', 'preparation-extension-statement'], ['45.57.64.72', 'preparation-extension-statement'], ['45.57.66.72', 'extension-extension-statement'], ['47.50.67.71', 'extension-extension-statement'], ['48.50.67.71', 'antecedent-extension-statement'], ['50.62.66.69', 'statement-extension-statement'], ['55.62.67.71', 'statement-extension-statement'], ['52.55.67.72', 'statement-extension-statement'], ['48.55.67.71', 'extension-extension-statement'], ['50.54.62.69', 'extension-extension-statement'], ['43.59.62.67', 'preparation-extension-statement'], ['48.60.64.67', 'extension-extension-statement'], ['52.55.60.72', 'extension-extension-statement'], ['52.55.62.72', 'statement-extension-statement'], ['48.60.64.67', 'extension-extension-statement'], ['53.60.65.69', 'extension-extension-statement'], ['55.60.65.69', 'extension-extension-statement'], ['57.57.60.64', 'extension-extension-statement'], ['57.57.62.65', 'preparation-extension-statement'], ['49.58.64.67', 'extension-extension-statement'], ['50.57.62.65', 'sta ...

# %%
#Минимальное необходимое число нот в обучающих произведениях
sequence_length = 38
sequence_length += 1

#Сортировка всех повторяющихся нот в множество неповторяющихся (Set)
notes_pitchnames = sorted(set(item for item in one_time_notes_set))

#Отображаем каждый аккорд или ноту на некоторое число (по сути Map)
notes_to_int = dict((note, number) for number, note in enumerate(notes_pitchnames))

network_input = []
network_input_without_normalisation = []
network_output = []

n_vocab_notes = len(one_time_notes_set)
n_vocab_speac = len(sorted_speac_to_int)

for i in range(0, len(notes) - sequence_length, 1):
    sequence_in = notes[i:i + sequence_length]

    # Берём только ноты, без speac
    sequence_out_notes = notes[i + sequence_length][0]  

    local_network_input = []
    local_network_input_without_normalisation = []
    for j in range(1, sequence_length):
        notes_in_input = sequence_in[j - 1][0]
        speac_in_input = sequence_in[j][1]      # Подаём не текущий speac, а следующий

        notes_to_number = notes_to_int[notes_in_input]
        speac_to_number = sorted_speac_to_int[speac_in_input]

        normalized_notes_to_number = notes_to_number / float(n_vocab_notes)  
        normalized_speac_to_number = speac_to_number / float(n_vocab_speac) 

        local_network_input.append([normalized_notes_to_number, normalized_speac_to_number])
        local_network_input_without_normalisation.append([notes_to_number, normalized_speac_to_number])

    network_input.append(local_network_input)
    network_input_without_normalisation.append(local_network_input_without_normalisation)

    network_output.append(notes_to_int[sequence_out_notes])

print("normalized network input[0]:")
print(network_input[0])
print("----------------")

n_patterns = len(network_input)
sequence_length -= 1

#Преобразование входной выборки в формат, удобный для работы с LSTM
network_input = numpy.reshape(network_input, (n_patterns, sequence_length, 2))  # подавать в нейросеть данные по 2 элемента
print("reshaped network input[0]:")
print(network_input[0])
print("----------------")

network_output = np_utils.to_categorical(network_output)
# Out:
# normalized network input[0]:
# [[0.2666112956810631, 0.7407407407407407], [0.2101328903654485, 0.7314814814814815], [0.21096345514950166, 0.7314814814814815], [0.08305647840531562, 0.7453703703703703], [0.07807308970099668, 0.7361111111111112], [0.2666112956810631, 0.7361111111111112], [0.3272425249169435, 0.7407407407407407], [0.46677740863787376, 0.7407407407407407], [0.574750830564784, 0.7407407407407407], [0.5872093023255814, 0.7407407407407407], [0.5980066445182725, 0.7407407407407407], [0.2707641196013289, 0.7453703703703703], [0.2599667774086379, 0.7314814814814815], [0.04152823920265781, 0.75], [0.19186046511627908, 0.75], [0.24086378737541528, 0.7453703703703703], [0.33637873754152825, 0.7453703703703703], [0.4601328903654485, 0.7407407407407407], [0.45598006644518274, 0.7407407407407407], [0.10382059800664452, 0.7407407407407407], [0.32475083056478404, 0.7361111111111112], [0.23338870431893688, 0.7361111111111112], [0.17857142857142858, 0.7361111111111112], [0.11129568106312292, 0.7361111111111112], [0.061461794019933555, 0.7361111111111112], [0.3372093023255814, 0.7407407407407407], [0.3313953488372093, 0.7453703703703703], [0.05398671096345515, 0.7407407407407407], [0.2666112956810631, 0.7407407407407407], [0.2101328903654485, 0.7314814814814815], [0.21096345514950166, 0.7314814814814815], [0.08305647840531562, 0.7453703703703703], [0.07807308970099668, 0.7361111111111112], [0.2666112956810631, 0.7361111111111112], [0.3272425249169435, 0.7407407407407407], [0.46677740863787376, 0.7407407407407407], [0.574750830564784, 0.7407407407407407], [0.5872093023255814, 0.7407407407407407]]
# ----------------
# reshaped network input[0]:
# [[0.2666113  0.74074074]
#  [0.21013289 0.73148148]
#  [0.21096346 0.73148148]
#  [0.08305648 0.74537037]
#  [0.07807309 0.73611111]
#  [0.2666113  0.73611111]
#  [0.32724252 0.74074074]
#  [0.46677741 0.74074074]
#  [0.57475083 0.74074074]
#  [0.5872093  0.74074074]
#  [0.59800664 0.74074074]
#  [0.27076412 0.74537037]
#  [0.25996678 0.73148148]
#  [0.04152824 0.75      ]
#  [0.19186047 0.75      ]
#  [0.24086379 0.74537037]
#  [0.33637874 0.74537037]
#  [0.46013289 0.74074074]
#  [0.45598007 0.74074074]
#  [0.1038206  0.74074074]
#  [0.32475083 0.73611111]
#  [0.2333887  0.73611111]
#  [0.17857143 0.73611111]
#  [0.11129568 0.73611111]
#  [0.06146179 0.73611111]
#  [0.3372093  0.74074074]
#  [0.33139535 0.74537037]
#  [0.05398671 0.74074074]
#  [0.2666113  0.74074074]
#  [0.21013289 0.73148148]
#  [0.21096346 0.73148148]
#  [0.08305648 0.74537037]
#  [0.07807309 0.73611111]
#  [0.2666113  0.73611111]
#  [0.32724252 0.74074074]
#  [0.46677741 0.74074074]
#  [0.57475083 0.74074074]
#  [0.5872093  0.74074074]]
# ----------------

# %%
def create_new_model(network_input, n_vocab):
  model = Sequential()
  model.add(LSTM(
        256,
        input_shape=(network_input.shape[1], 
                     network_input.shape[2]),
        return_sequences=True
    ))
  model.add(Dropout(0.3))
  model.add(LSTM(512, return_sequences=True))
  model.add(Dropout(0.3))
  model.add(LSTM(256))
  model.add(Dense(256))
  model.add(Dropout(0.3))
  model.add(Dense(n_vocab))
  model.add(Activation('softmax'))

  model.summary()

  return model

# %%
with strategy.scope():
    model_only_notes = create_new_model(network_input, n_vocab_notes)
    model_only_notes.compile(loss='categorical_crossentropy', optimizer='rmsprop')
    print("model_only_notes is compilled")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 38, 256)           265216
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 38, 256)           0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 38, 512)           1574912
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 38, 512)           0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 256)               787456
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1204)              309428
# _________________________________________________________________
# activation_1 (Activation)    (None, 1204)              0
# =================================================================
# Total params: 3,002,804
# Trainable params: 3,002,804
# Non-trainable params: 0
# _________________________________________________________________
# model_only_notes is compilled

# %%
model_only_notes.fit(network_input, network_output, epochs=200, batch_size=64)
# Out:
# Epoch 1/200
# 43/43 [==============================] - 13s 92ms/step - loss: 7.0475
# Epoch 2/200
# 43/43 [==============================] - 1s 27ms/step - loss: 6.7892
# Epoch 3/200
# 43/43 [==============================] - 1s 27ms/step - loss: 6.7151
# Epoch 4/200
# 43/43 [==============================] - 1s 27ms/step - loss: 6.6115
# Epoch 5/200
# 43/43 [==============================] - 1s 27ms/step - loss: 6.5541
# Epoch 6/200
# 43/43 [==============================] - 1s 27ms/step - loss: 6.5010
# Epoch 7/200
# 43/43 [==============================] - 1s 27ms/step - loss: 6.4712
# Epoch 8/200
# 43/43 [==============================] - 1s 27ms/step - loss: 6.4187
# Epoch 9/200
# 43/43 [==============================] - 1s 27ms/step - loss: 6.2985
# Epoch 10/200
# 43/43 [==============================] - 1s 26ms/step - loss: 6.2907
# Epoch 11/200
# 43/43 [==============================] - 1s 27ms/step - loss: 6.2353
# Epoch 12/200
# 43/43 [==============================] - 1s 27ms/step - loss: 6.0816
# Epoch 13/200
# 43/43 [==============================] - 1s 27ms/step - loss: 6.0342
# Epoch 14/200
# 43/43 [==============================] - 1s 26ms/step - loss: 5.8881
# Epoch 15/200
# 43/43 [==============================] - 1s 26ms/step - loss: 5.7880
# Epoch 16/200
# 43/43 [==============================] - 1s 26ms/step - loss: 5.6817
# Epoch 17/200
# 43/43 [==============================] - 1s 26ms/step - loss: 5.5357
# Epoch 18/200
# 43/43 [==============================] - 1s 26ms/step - loss: 5.4243
# Epoch 19/200
# 43/43 [==============================] - 1s 26ms/step - loss: 5.2971
# Epoch 20/200
# 43/43 [==============================] - 1s 26ms/step - loss: 5.1592
# Epoch 21/200
# 43/43 [==============================] - 1s 26ms/step - loss: 4.9974
# Epoch 22/200
# 43/43 [==============================] - 1s 26ms/step - loss: 4.8510
# Epoch 23/200
# 43/43 [==============================] - 1s 26ms/step - loss: 4.6916
# Epoch 24/200
# 43/43 [==============================] - 1s 26ms/step - loss: 4.6167
# Epoch 25/200
# 43/43 [==============================] - 1s 27ms/step - loss: 4.4700
# Epoch 26/200
# 43/43 [==============================] - 1s 26ms/step - loss: 4.2982
# Epoch 27/200
# 43/43 [==============================] - 1s 26ms/step - loss: 4.1341
# Epoch 28/200
# 43/43 [==============================] - 1s 26ms/step - loss: 3.9882
# Epoch 29/200
# 43/43 [==============================] - 1s 26ms/step - loss: 3.8795
# Epoch 30/200
# 43/43 [==============================] - 1s 27ms/step - loss: 3.7881
# Epoch 31/200
# 43/43 [==============================] - 1s 27ms/step - loss: 3.6344
# Epoch 32/200
# 43/43 [==============================] - 1s 26ms/step - loss: 3.5628
# Epoch 33/200
# 43/43 [==============================] - 1s 27ms/step - loss: 3.3779
# Epoch 34/200
# 43/43 [==============================] - 1s 27ms/step - loss: 3.3422
# Epoch 35/200
# 43/43 [==============================] - 1s 26ms/step - loss: 3.2339
# Epoch 36/200
# 43/43 [==============================] - 1s 27ms/step - loss: 3.0908
# Epoch 37/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.9614
# Epoch 38/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.9381
# Epoch 39/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.8368
# Epoch 40/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.7452
# Epoch 41/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.7499
# Epoch 42/200
# 43/43 [==============================] - 1s 26ms/step - loss: 2.5945
# Epoch 43/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.5172
# Epoch 44/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.4652
# Epoch 45/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.4109
# Epoch 46/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.3863
# Epoch 47/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.3075
# Epoch 48/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.3098
# Epoch 49/200
# 43/43 [==============================] - 1s 26ms/step - loss: 2.1331
# Epoch 50/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.1277
# Epoch 51/200
# 43/43 [==============================] - 1s 26ms/step - loss: 2.1245
# Epoch 52/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.0456
# Epoch 53/200
# 43/43 [==============================] - 1s 27ms/step - loss: 2.0748
# Epoch 54/200
# 43/43 [==============================] - 1s 28ms/step - loss: 1.9616
# Epoch 55/200
# 43/43 [==============================] - 1s 26ms/step - loss: 1.9488
# Epoch 56/200
# 43/43 [==============================] - 1s 28ms/step - loss: 1.8781
# Epoch 57/200
# 43/43 [==============================] - 1s 28ms/step - loss: 1.8895
# Epoch 58/200
# 43/43 [==============================] - 1s 28ms/step - loss: 1.8064
# Epoch 59/200
# 43/43 [==============================] - 1s 28ms/step - loss: 1.7710
# Epoch 60/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.7495
# Epoch 61/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.6986
# Epoch 62/200
# 43/43 [==============================] - 1s 28ms/step - loss: 1.6578
# Epoch 63/200
# 43/43 [==============================] - 1s 28ms/step - loss: 1.6087
# Epoch 64/200
# 43/43 [==============================] - 1s 26ms/step - loss: 1.5985
# Epoch 65/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.5306
# Epoch 66/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.4971
# Epoch 67/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.4570
# Epoch 68/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.4692
# Epoch 69/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.4319
# Epoch 70/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.3930
# Epoch 71/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.3759
# Epoch 72/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.3416
# Epoch 73/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.3514
# Epoch 74/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.2966
# Epoch 75/200
# 43/43 [==============================] - 1s 26ms/step - loss: 1.2343
# Epoch 76/200
# 43/43 [==============================] - 1s 26ms/step - loss: 1.2278
# Epoch 77/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.2107
# Epoch 78/200
# 43/43 [==============================] - 1s 26ms/step - loss: 1.2080
# Epoch 79/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.1811
# Epoch 80/200
# 43/43 [==============================] - 1s 26ms/step - loss: 1.1295
# Epoch 81/200
# 43/43 [==============================] - 1s 28ms/step - loss: 1.1341
# Epoch 82/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.0817
# Epoch 83/200
# 43/43 [==============================] - 1s 28ms/step - loss: 1.1003
# Epoch 84/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.0043
# Epoch 85/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.0067
# Epoch 86/200
# 43/43 [==============================] - 1s 27ms/step - loss: 1.0444
# Epoch 87/200
# 43/43 [==============================] - 1s 26ms/step - loss: 0.9954
# Epoch 88/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.9249
# Epoch 89/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.9458
# Epoch 90/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.9121
# Epoch 91/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.8732
# Epoch 92/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.8708
# Epoch 93/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.8444
# Epoch 94/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.8401
# Epoch 95/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.8090
# Epoch 96/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.8160
# Epoch 97/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.7516
# Epoch 98/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.7601
# Epoch 99/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.7601
# Epoch 100/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.7383
# Epoch 101/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.7277
# Epoch 102/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.7316
# Epoch 103/200
# 43/43 [==============================] - 1s 29ms/step - loss: 0.7104
# Epoch 104/200
# 43/43 [==============================] - 1s 30ms/step - loss: 0.6736
# Epoch 105/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.7127
# Epoch 106/200
# 43/43 [==============================] - 1s 29ms/step - loss: 0.6029
# Epoch 107/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.6657
# Epoch 108/200
# 43/43 [==============================] - 1s 29ms/step - loss: 0.6113
# Epoch 109/200
# 43/43 [==============================] - 1s 29ms/step - loss: 0.5845
# Epoch 110/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.5921
# Epoch 111/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.5830
# Epoch 112/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.5840
# Epoch 113/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.5747
# Epoch 114/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.5617
# Epoch 115/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.5117
# Epoch 116/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.5205
# Epoch 117/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.5217
# Epoch 118/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.4669
# Epoch 119/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.5145
# Epoch 120/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.4601
# Epoch 121/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.4629
# Epoch 122/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.4777
# Epoch 123/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.5048
# Epoch 124/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.4161
# Epoch 125/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.4929
# Epoch 126/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.4447
# Epoch 127/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.4514
# Epoch 128/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.4405
# Epoch 129/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.4174
# Epoch 130/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.4313
# Epoch 131/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.3729
# Epoch 132/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.3942
# Epoch 133/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.3762
# Epoch 134/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.3700
# Epoch 135/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.3904
# Epoch 136/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.3689
# Epoch 137/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.3674
# Epoch 138/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.3531
# Epoch 139/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.3466
# Epoch 140/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.3440
# Epoch 141/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.3110
# Epoch 142/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.3527
# Epoch 143/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.3222
# Epoch 144/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.3459
# Epoch 145/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.3088
# Epoch 146/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.3418
# Epoch 147/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2826
# Epoch 148/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.3198
# Epoch 149/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.3020
# Epoch 150/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2904
# Epoch 151/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2937
# Epoch 152/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2780
# Epoch 153/200
# 43/43 [==============================] - 1s 29ms/step - loss: 0.2940
# Epoch 154/200
# 43/43 [==============================] - 1s 29ms/step - loss: 0.3019
# Epoch 155/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2704
# Epoch 156/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2804
# Epoch 157/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2862
# Epoch 158/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2742
# Epoch 159/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2859
# Epoch 160/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2828
# Epoch 161/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2479
# Epoch 162/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2396
# Epoch 163/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2591
# Epoch 164/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2722
# Epoch 165/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2908
# Epoch 166/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2629
# Epoch 167/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2474
# Epoch 168/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2508
# Epoch 169/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2214
# Epoch 170/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2426
# Epoch 171/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2426
# Epoch 172/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2166
# Epoch 173/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2521
# Epoch 174/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2318
# Epoch 175/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2365
# Epoch 176/200
# 43/43 [==============================] - 1s 26ms/step - loss: 0.2404
# Epoch 177/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2309
# Epoch 178/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2513
# Epoch 179/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2195
# Epoch 180/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2182
# Epoch 181/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2209
# Epoch 182/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2254
# Epoch 183/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2294
# Epoch 184/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2267
# Epoch 185/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2364
# Epoch 186/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2450
# Epoch 187/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1953
# Epoch 188/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2111
# Epoch 189/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2293
# Epoch 190/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1985
# Epoch 191/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.1983
# Epoch 192/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.1834
# Epoch 193/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2023
# Epoch 194/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.2175
# Epoch 195/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.1911
# Epoch 196/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1865
# Epoch 197/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1870
# Epoch 198/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2153
# Epoch 199/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2187
# Epoch 200/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1740

# %%
  # start = numpy.random.randint(0, len(network_input)-1)
  start = 0 # выбираем индекс, начиная с которого для генерации будет использоваться существующая структура 
  pattern = copy.deepcopy(network_input[start]) # первые N нот не генерируются, а берутся из этого произведения

  int_to_note = dict((number, note) for number, note in enumerate(notes_pitchnames))

  predicted_outputs = []
  predicted_speac = []

  notes_count = 50
  # generate n notes
  for note_index in range(notes_count):
        # print("------------")
        print("generating ", note_index, " note")
        
        prediction_input = numpy.reshape(pattern, (1, len(pattern), 2))
        prediction_input = copy.deepcopy(prediction_input)
        # print("prediction_input1 = ", prediction_input)
        # print("pattern1 = ", pattern)

        for i in range(1, len(prediction_input[0]) + 1):
            prediction_input[0][i - 1][0] /= float(n_vocab_notes) 
            prediction_input[0][i - 1][1] /= float(n_vocab_speac) 

        # print("prediction_input2 = ", prediction_input)
        # print("pattern2 = ", pattern)

        prediction_only_notes = model_only_notes.predict(prediction_input, verbose=0)

        index_only_notes = numpy.argmax(prediction_only_notes)
        result_only_notes = int_to_note[index_only_notes]
        predicted_outputs.append(result_only_notes)

        next_speac = notes[start + sequence_length + note_index][1] 
        speac_to_number = sorted_speac_to_int[next_speac]
        predicted_speac.append(next_speac)

        pattern = numpy.append(pattern, [[index_only_notes, speac_to_number]], axis=0) 
        # pattern = numpy.append(pattern, [[index_only_notes / float(n_vocab_notes) , speac_to_number /float(n_vocab_speac)]], axis=0) # тут точно не надо делить???
        pattern = pattern[1:len(pattern)]
        # print("pattern3 = ", pattern)
# Out:
# generating  0  note
# generating  1  note
# generating  2  note
# generating  3  note
# generating  4  note
# generating  5  note
# generating  6  note
# generating  7  note
# generating  8  note
# generating  9  note
# generating  10  note
# generating  11  note
# generating  12  note
# generating  13  note
# generating  14  note
# generating  15  note
# generating  16  note
# generating  17  note
# generating  18  note
# generating  19  note
# generating  20  note
# generating  21  note
# generating  22  note
# generating  23  note
# generating  24  note
# generating  25  note
# generating  26  note
# generating  27  note
# generating  28  note
# generating  29  note
# generating  30  note
# generating  31  note
# generating  32  note
# generating  33  note
# generating  34  note
# generating  35  note
# generating  36  note
# generating  37  note
# generating  38  note
# generating  39  note
# generating  40  note
# generating  41  note
# generating  42  note
# generating  43  note
# generating  44  note
# generating  45  note
# generating  46  note
# generating  47  note
# generating  48  note
# generating  49  note

# %%
print(predicted_speac)
# Out:
# ['extension-preparation-statement', 'extension-preparation-statement', 'statement-preparation-statement', 'antecedent-preparation-statement', 'statement-extension-statement', 'statement-extension-statement', 'extension-extension-statement', 'extension-extension-statement', 'extension-extension-statement', 'extension-extension-statement', 'extension-extension-statement', 'preparation-extension-statement', 'preparation-extension-statement', 'preparation-extension-statement', 'preparation-extension-statement', 'preparation-extension-statement', 'extension-extension-statement', 'statement-extension-statement', 'statement-extension-statement', 'preparation-extension-statement', 'preparation-extension-statement', 'extension-extension-statement', 'extension-extension-statement', 'antecedent-extension-statement', 'statement-extension-statement', 'statement-extension-statement', 'statement-extension-statement', 'extension-extension-statement', 'extension-extension-statement', 'preparation-extension-statement', 'extension-extension-statement', 'extension-extension-statement', 'statement-extension-statement', 'extension-extension-statement', 'extension-extension-statement', 'extension-extension-statement', 'extension-extension-statement', 'preparation-extension-statement', 'extension-extension-statement', 'statement-extension-statement', 'statement-extension-statement', 'extension-extension-statement', 'antecedent-extension-statement', 'antecedent-extension-statement', 'preparation-extension-statement', 'extension-extension-statement', 'extension-extension-statement', 'preparation-extension-statement', 'preparation-extension-statement', 'extension-extension-statement']

# %%
import music21
from music21 import *

# %%
create_new_midi(predicted_outputs, "speac_example_n=" + str(sequence_length) + ".mid")

# %%
chorale = []
for i in range(1, notes_count + 1):
    chorale.append(notes[start + i - 1][0])

print(chorale)

create_new_midi(chorale, "chorale.mid")
# Out:
# ['48.60.64.67', '47.62.62.67', '47.62.64.67', '43.60.65.67', '43.59.65.67', '48.60.64.67', '50.53.62.70', '52.55.62.70', '53.57.60.69', '53.58.60.69', '53.60.65.69', '48.60.65.67', '48.58.64.67', '41.57.60.65', '47.55.62.67', '48.55.60.64', '50.55.60.64', '52.55.60.60', '52.53.59.62', '45.52.60.64', '50.50.57.66', '48.50.57.66', '47.50.62.67', '45.55.60.67', '43.55.59.67', '50.55.60.69', '50.54.60.69', '43.50.59.67', '48.60.64.67', '47.62.62.67', '47.62.64.67', '43.60.65.67', '43.59.65.67', '48.60.64.67', '50.53.62.70', '52.55.62.70', '53.57.60.69', '53.58.60.69', '53.60.65.69', '48.60.65.67', '48.58.64.67', '41.57.60.65', '47.55.62.67', '48.55.60.64', '50.55.60.64', '52.55.60.60', '52.53.59.62', '45.52.60.64', '50.50.57.66', '48.50.57.66']
